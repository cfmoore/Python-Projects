# %% [markdown]
# # Lab9 - Python Using Web APIs

# %% [markdown]
# ### Author: <font color='red'> Charles Moore </font>

# %% [markdown]
# ## Lab 9 - PART A (10 points)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>ATTENTION:</b> PART A of this lab corresponds to the YouTube video:
#     <em>Python: Using Web APIs Tutorial | HTTP Requests by Joe James</em><br>
#     <b>Watch this YouTube video and complete the code to complete PART A of the Lab.<b> (13m 30s)<br><br>
#     <b>URL: https://youtu.be/ChwSD5e0Qs0 </b>
# </div>

# %% [markdown]
# ## URL: https://youtu.be/ChwSD5e0Qs0

# %% [markdown]
# (c) 2019, Joe James.
# MIT License.
#
# Tutorial on using the [Requests](http://docs.python-requests.org/en/master/user/quickstart/) library to access HTTP requests, GET, POST, PUT, DELETE, HEAD, OPTIONS.
# This notebook also covers how to use the Python [JSON](https://docs.python.org/3/library/json.html) library to parse values out of a GET response.
# If you don't have the requests library installed you can run 'pip install requests' or some equivalent command for your system in the console window.

# %%
# Required import statements
import requests
import json

# %% [markdown]
# #### HTTP Request types (Each URI = API Endpoint)
# An example of each type of HTTP Request is provided below.<br>
# In each case, <strong>r</strong> = the Response object returned by the Server.

# %%
# CODE PROVIDED (Sample HTTP Requests) ~ GET, POST, PUT, DELETE, HEAD and OPTIONS requests

# Sample GET request to the GitHub API /events endpoint
r = requests.get('https://api.github.com/events')
r = requests.post('https://httpbin.org/post', data = {'name':'Joe'})
r = requests.put('https://httpbin.org/put', data = {'name':'Joe'})
r = requests.delete('https://httpbin.org/delete')
r = requests.head('https://httpbin.org/get')
r = requests.options('https://httpbin.org/get')

# %% [markdown]
# ### GET Requests - Passing Parameters in URLs
# A URL that returns an HTTP response in JSON format is called an API endpoint.
# Here's an example, https://httpbin.org/get
#
# With GET requests we can add parameters onto the URL to retrieve specific data.
# We define the __params__ as a __dictionary__, and add __params =__ _payload_ to the Request.
# The Requests library builds the whole URL for us.

# %% [markdown]
# <span style="color:blue">
# <ul>
#     <li>Create a <strong>payload</strong> variable as shown in the tutorial using a dictionary {'key1': 'value1', 'key2': 'value2'}</li>
#     <li>Enter the code for a <strong>GET</strong> to <strong>https://httpbin.org/get</strong> passing the <strong>payload</strong> variable - save the response in variable <strong>r</strong></li>
#     <li>Print the <strong>url</strong> so you can see the generated URL</li>
#     </ul>
# </span>

# %%
# INSERT GET CODE USING PAYLOAD 
payload = {'key1':'value1', 'key2':'value2'}
r = requests.get('https://httpbin.org/get', params=payload)
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2

# %% [markdown]
# **Passing a List as a parameter**
# Note that when creating the dictionary payload with {key:value} pairs, a value(s) can also be a __list__.

# %% [markdown]
# <div class="alert alert-block alert-info">
#     <b>NOTE:</b> There are many different properties included in the HTTP Request response. <br>To see the properties that can be extracted from the Response object, check out the list (with runnable examples) at W3SCHOOLS.COM <br><strong> https://www.w3schools.com/python/ref_requests_response.asp</strong></div>

# %% [markdown]
# <span style="color:blue">
#     Following the tutorial ...
#     <ul>
#         <li>Create a new <strong><em>payload</em></strong> variable using the dictionary {'key1': 'value1', 'key2': ['value2', 'value3']} </li>
#         <li> Enter the code for a <strong>GET</strong> request passing the <strong>payload</strong> variable - save the response in variable <strong>r</strong></li>
#         <li>Print the response (<strong>r</strong>) values: URL, ENCODING, STATUS_CODE, HEADERS, TEXT, CONTENT and JSON - each on a separate line as shown in the video</li>
#             </ul>
# </span>

# %%
# INSERT GET CODE USING PAYLOAD WITH A LIST and PRINT RESPONSE VALUES
payload = {'key1':'value1', 'key2':['value2', 'value3']}
r = requests.get('https://httpbin.org/get', params=payload)
print('URL: ',r.url)
print('ENCODING: ',r.encoding)
print('STATUS_CODE: ',r.status_code)
print('HEADERS: ',r.headers)
print('TEXT: ',r.text)
print('CONTENT:',r.content)
print('JSON: ',r.json)
# Out:
# URL:  https://httpbin.org/get?key1=value1&key2=value2&key2=value3
# ENCODING:  utf-8
# STATUS_CODE:  200
# HEADERS:  {'Date': 'Tue, 26 Oct 2021 19:09:22 GMT', 'Content-Type': 'application/json', 'Content-Length': '422', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}
# TEXT:  {
#   "args": {
#     "key1": "value1",
#     "key2": [
#       "value2",
#       "value3"
#     ]
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-61785262-2119992d00c20cf336664526"
#   },
#   "origin": "107.134.20.152",
#   "url": "https://httpbin.org/get?key1=value1&key2=value2&key2=value3"
# }
#
# CONTENT: b'{\n  "args": {\n    "key1": "value1", \n    "key2": [\n      "value2", \n      "value3"\n    ]\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.25.1", \n    "X-Amzn-Trace-Id": "Root=1-61785262-2119992d00c20cf336664526"\n  }, \n  "origin": "107.134.20.152", \n  "url": "https://httpbin.org/get?key1=value1&key2=value2&key2=value3"\n}\n'
# JSON:  <bound method Response.json of <Response [200]>>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>LOOK AT THE OUTPUT GENERATED!</b> Check out the values printed by the previous print statements -- you should understand and/or recognize most of the information displayed.
# </div>

# %% [markdown]
# ### POST Requests
# We can also add parameters to a POST request in dictionary format, but the parameters are provided using a __data=payload__ syntax where _payload_ is the dictionary.
# - POST requests are used to __upload new records__ to the server.
# -POST requests would typically be used to get data from a __web form__ and __submit__ it to the server.

# %% [markdown]
# <span style="color:blue">
#     Following the tutorial ...
#     <ul>
#         <li> Enter the code for a <strong>POST</strong> request with <strong>data = {'name':'Joe'}</strong> - save the response in variable <strong>r</strong></li>
#         <li>Print the response (<strong>r</strong>) value: TEXT</li>
#     </ul>
# </span>

# %%
# INSERT POST CODE USING DATA = {'name': 'Joe'}
r= requests.post('https://httpbin.org/post', data = {'name':'Joe'})
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "name": "Joe"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "8",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-61785264-0851f6d50e65169b5ac4e055"
#   },
#   "json": null,
#   "origin": "107.134.20.152",
#   "url": "https://httpbin.org/post"
# }

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>LOOK AT THE OUTPUT GENERATED!</b> Specifically the "form" and "Content-Length" values
# </div>

# %% [markdown]
# <span style="color:blue">
#     Following the tutorial ...
#     <ul>
#         <li>Create a new <strong><em>payload</em></strong> variable using the dictionary {'key1': 'value1', 'key2': 'value2'} </li>
#         <li> Enter the code for a <strong>POST</strong> request with <strong>data = payload</strong> - save the response in variable <strong>r</strong></li>
#         <li>Print the response (<strong>r</strong>) value: TEXT</li>
#     </ul>
# </span>

# %%
# INSERT POST CODE USING DATA = payload
payload = {'key1':'value1', 'key2':'value2'}
r = requests.post('https://httpbin.org/post', data=payload)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.25.1",
#     "X-Amzn-Trace-Id": "Root=1-61785267-28eccb5b43579d9d2ee3208d"
#   },
#   "json": null,
#   "origin": "107.134.20.152",
#   "url": "https://httpbin.org/post"
# }

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>LOOK AT THE OUTPUT GENERATED!</b> Specifically the "form" and "Content-Length" values which will be different than previous POST request.
# </div>

# %% [markdown]
# ### Using Requests to GET Currency Exchange Data

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>ATTENTION:</strong> The endpoint referenced in the tutorial [https://api.exchangeratesapi.io/latest] to GET foreign currency exchange rates,
#     now requires an <strong>API Access Key!!!</strong><br><br><strong>Use the following URL instead: https://open.er-api.com/v6/latest </strong>
# </div>

# %% [markdown]
# <span style="color:blue">
#     Using the alternate URL provided (open-er-api.com) ...
#     <ul>
#     <li>Enter the code for a <strong>GET</strong> request using the updated <strong>exchange rates API</strong> URL provided</li>
#     <li>Save the response in variable <strong>r</strong></li>
#     </ul>
# </span>

# %%
# INSERT GET CODE USING ALTERNATE URL TO GET LATEST EXCHANGE RATES
url = 'https://open.er-api.com/v6/latest'
r = requests.get(url)

# %%
# DO NOT MODIFY !!!
# Re-printing the the response in a format that is easier to read
json_data = r.json()
print(json.dumps(json_data, indent=4))
# Out:
# {
#     "result": "success",
#     "provider": "https://www.exchangerate-api.com",
#     "documentation": "https://www.exchangerate-api.com/docs/free",
#     "terms_of_use": "https://www.exchangerate-api.com/terms",
#     "time_last_update_unix": 1635206551,
#     "time_last_update_utc": "Tue, 26 Oct 2021 00:02:31 +0000",
#     "time_next_update_unix": 1635294541,
#     "time_next_update_utc": "Wed, 27 Oct 2021 00:29:01 +0000",
#     "time_eol_unix": 0,
#     "base_code": "USD",
#     "rates": {
#         "USD": 1,
#         "AED": 3.67,
#         "AFN": 85.18,
#         "ALL": 105.06,
#         "AMD": 479.06,
#         "ANG": 1.79,
#         "AOA": 604.28,
#         "ARS": 99.63,
#         "AUD": 1.33,
#         "AWG": 1.79,
#         "AZN": 1.71,
#         "BAM": 1.68,
#         "BBD": 2,
#         "BDT": 85.78,
#         "BGN": 1.68,
#         "BHD": 0.376,
#         "BIF": 1991.04,
#         "BMD": 1,
#         "BND": 1.35,
#         "BOB": 6.91,
#         "BRL": 5.64,
#         "BSD": 1,
#         "BTN": 75,
#         "BWP": 11.24,
#         "BYN": 2.43,
#         "BZD": 2,
#         "CAD": 1.23,
#         "CDF": 1999.73,
#         "CHF": 0.918,
#         "CLP": 816.65,
#         "CNY": 6.38,
#         "COP": 3760.49,
#         "CRC": 630.22,
#         "CUC": 1,
#         "CUP": 25,
#         "CVE": 94.82,
#         "CZK": 22.16,
#         "DJF": 177.72,
#         "DKK": 6.42,
#         "DOP": 56.47,
#         "DZD": 137.86,
#         "EGP": 15.71,
#         "ERN": 15,
#         "ETB": 47.56,
#         "EUR": 0.86,
#         "FJD": 2.07,
#         "FKP": 0.726,
#         "FOK": 6.42,
#         "GBP": 0.726,
#         "GEL": 3.14,
#         "GGP": 0.726,
#         "GHS": 6.09,
#         "GIP": 0.726,
#         "GMD": 52.95,
#         "GNF": 9757.91,
#         "GTQ": 7.76,
#         "GYD": 210.81,
#         "HKD": 7.77,
#         "HNL": 24.2,
#         "HRK": 6.48,
#         "HTG": 99.97,
#         "HUF": 315.1,
#         "IDR": 14108.95,
#         "ILS": 3.22,
#         "IMP": 0.726,
#         "INR": 75,
#         "IQD": 1470.37,
#         "IRR": 41989.72,
#         "ISK": 129.07,
#         "JMD": 152.9,
#         "JOD": 0.709,
#         "JPY": 113.68,
#         "KES": 111.2,
#         "KGS": 85.09,
#         "KHR": 4102.76,
#         "KID": 1.33,
#         "KMF": 423.07,
#         "KRW": 1170.79,
#         "KWD": 0.3,
#         "KYD": 0.833,
#         "KZT": 426.57,
#         "LAK": 10201.03,
#         "LBP": 1507.5,
#         "LKR": 201.16,
#         "LRD": 162.99,
#         "LSL": 14.74,
#         "LYD": 4.59,
#         "MAD": 9.07,
#         "MDL": 17.5,
#         "MGA": 3983.66,
#         "MKD": 53.21,
#         "MMK": 1868.38,
#         "MNT": 2873.71,
#         "MOP": 8,
#         "MRU": 36.47,
#         "MUR": 42.83,
#         "MVR": 15.46,
#         "MWK": 817.45,
#         "MXN": 20.19,
#         "MYR": 4.15,
#         "MZN": 64.26,
#         "NAD": 14.74,
#         "NGN": 422.38,
#         "NIO": 35.35,
#         "NOK": 8.35,
#         "NPR": 120,
#         "NZD": 1.4,
#         "OMR": 0.384,
#         "PAB": 1,
#         "PEN": 3.97,
#         "PGK": 3.52,
#         "PHP": 50.7,
#         "PKR": 174.44,
#         "PLN": 3.97,
#         "PYG": 6904.06,
#         "QAR": 3.64,
#         "RON": 4.25,
#         "RSD": 101.56,
#         "RUB": 69.97,
#         "RWF": 1019.94,
#         "SAR": 3.75,
#         "SBD": 7.97,
#         "SCR": 14.4,
#         "SDG": 441.27,
#         "SEK": 8.6,
#         "SGD": 1.35,
#         "SHP": 0.726,
#         "SLL": 10676,
#         "SOS": 582.58,
#         "SRD": 21.63,
#         "SSP": 176.54,
#         "STN": 21.07,
#         "SYP": 1686.39,
#         "SZL": 14.74,
#         "THB": 33.16,
#         "TJS": 11.32,
#         "TMT": 3.51,
#         "TND": 2.83,
#         "TOP": 2.23,
#         "TRY": 9.64,
#         "TTD": 6.8,
#         "TVD": 1.33,
#         "TWD": 27.89,
#         "TZS": 2309.07,
#         "UAH": 26.34,
#         "UGX": 3600.53,
#         "UYU": 43.92,
#         "UZS": 10703.01,
#         "VES": 4.23,
#         "VND": 22809.32,
#         "VUV": 110.6,
#         "WST": 2.55,
#         "XAF": 564.1,
#         "XCD": 2.7,
#         "XDR": 0.706,
#         "XOF": 564.1,
#         "XPF": 102.62,
#         "YER": 251.36,
#         "ZAR": 14.74,
#         "ZMW": 17.1
#     }
# }

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>THE DEFAULT ...</b> base was set to USD ($). This can be verified by looking in the JSON for <b>"base_code": "USD"</b>.
# </div>

# %% [markdown]
# <span style="color:blue">
#     Diverting slightly from the tutorial, but still using the alternate URL provided (open-er-api.com) ...
#     <ul>
#     <li>Enter the code for a <strong>GET</strong> request but this time get the exchange rates for the EURO instead. Add <b>/EUR</b> to the end of the URL.
#     <li>Save the response in variable <strong>r_euro</strong></li>
#     <li>Print the response (<strong>r_euro</strong>) value: TEXT</li>
#     </ul>
#     <p><b>Remember to change the response variable to r_euro</b> so you don't over-write the USD response information</p>
# </span>

# %%
# INSERT GET CODE USING ALTERNATE URL TO GET EUR EXCHANGE RATES
url = 'https://open.er-api.com/v6/latest/'
r_euro = requests.get(url+'/EUR')
print(r_euro.text)
# Out:
# {"result":"success","provider":"https://www.exchangerate-api.com","documentation":"https://www.exchangerate-api.com/docs/free","terms_of_use":"https://www.exchangerate-api.com/terms","time_last_update_unix":1635206551,"time_last_update_utc":"Tue, 26 Oct 2021 00:02:31 +0000","time_next_update_unix":1635294621,"time_next_update_utc":"Wed, 27 Oct 2021 00:30:21 +0000","time_eol_unix":0,"base_code":"EUR","rates":{"EUR":1,"AED":4.27,"AFN":92.9,"ALL":121.45,"AMD":554.5,"ANG":2.08,"AOA":697.01,"ARS":115.58,"AUD":1.55,"AWG":2.08,"AZN":1.98,"BAM":1.96,"BBD":2.33,"BDT":99.25,"BGN":1.96,"BHD":0.437,"BIF":2310.1,"BMD":1.16,"BND":1.56,"BOB":8,"BRL":6.55,"BSD":1.16,"BTN":87.12,"BWP":13.03,"BYN":2.81,"BZD":2.33,"CAD":1.43,"CDF":2325.38,"CHF":1.07,"CLP":949.55,"CNY":7.42,"COP":4348.69,"CRC":730.49,"CUC":1.16,"CUP":29.07,"CVE":110.27,"CZK":25.75,"DJF":206.65,"DKK":7.46,"DOP":65.47,"DZD":159.82,"EGP":18.22,"ERN":17.44,"ETB":55.24,"FJD":2.4,"FKP":0.845,"FOK":7.46,"GBP":0.845,"GEL":3.64,"GGP":0.845,"GHS":7.06,"GIP":0.845,"GMD":61.58,"GNF":11346.92,"GTQ":8.99,"GYD":245.14,"HKD":9.03,"HNL":27.99,"HRK":7.53,"HTG":116.25,"HUF":366.17,"IDR":16357.27,"ILS":3.74,"IMP":0.845,"INR":87.12,"IQD":1709.81,"IRR":48579.32,"ISK":150.05,"JMD":177.05,"JOD":0.824,"JPY":132.04,"KES":129.01,"KGS":98.49,"KHR":4770.87,"KID":1.55,"KMF":491.97,"KRW":1361.23,"KWD":0.348,"KYD":0.969,"KZT":494.49,"LAK":11826.52,"LBP":1752.89,"LKR":233.49,"LRD":189.37,"LSL":17.11,"LYD":5.34,"MAD":10.52,"MDL":20.31,"MGA":4611.74,"MKD":61.7,"MMK":2148.88,"MNT":3341.68,"MOP":9.3,"MRU":42.41,"MUR":49.65,"MVR":17.9,"MWK":945.27,"MXN":23.46,"MYR":4.82,"MZN":74.32,"NAD":17.11,"NGN":494.42,"NIO":40.9,"NOK":9.7,"NPR":139.39,"NZD":1.62,"OMR":0.447,"PAB":1.16,"PEN":4.61,"PGK":4.07,"PHP":58.9,"PKR":202.39,"PLN":4.61,"PYG":7981.99,"QAR":4.23,"RON":4.94,"RSD":117.52,"RUB":81.33,"RWF":1182.05,"SAR":4.36,"SBD":9.24,"SCR":16.45,"SDG":513.13,"SEK":9.99,"SGD":1.56,"SHP":0.845,"SLL":12414.51,"SOS":677.45,"SRD":25.15,"SSP":205.11,"STN":24.5,"SYP":1460.95,"SZL":17.11,"THB":38.53,"TJS":13.09,"TMT":4.07,"TND":3.28,"TOP":2.59,"TRY":11.2,"TTD":8.01,"TVD":1.55,"TWD":32.39,"TZS":2675.92,"UAH":30.63,"UGX":4142.54,"USD":1.16,"UYU":50.92,"UZS":12322.22,"VES":4.92,"VND":26391.86,"VUV":128.56,"WST":2.96,"XAF":655.96,"XCD":3.14,"XDR":0.822,"XOF":655.96,"XPF":119.33,"YER":290.87,"ZAR":17.11,"ZMW":19.81}}

# %% [markdown]
# ### Decoding JSON data
# Now that we have the USD ($) exchange rates in JSON format. We need to convert that to usable data.
# The JSON library basically has two functions:
# - __json.loads( )__ ~ converts a text string into Python dict/list objects.
# - __json.dumps( )__ ~ converts dict/list objects into a string.
#
# Let's decode the JSON data into a dictionary, then get the rate for GBP (&#163;), convert it to a float, and do a conversion.

# %% [markdown]
# <span style="color:blue">
#     Insert the code from the tutorial to use <strong>json.loads</strong> to convert the text string into a Python dict/list<br>
#     Print the rates and calculate the conversion (as shown in tutorial)
# </span>
# <span style="color:blue">
#     Following the tutorial ...
#     <ul>
#         <li>Use <strong>json.loads</strong> to convert the text string into a Python dictionary</li>
#         <ul>
#             <li>referencing the <strong>text</strong> portion of the response <strong>r</strong> object get the <strong>['rates']</strong> values</li>
#             <li>assign the results to variable <strong>rates_json</strong></li>
#         </ul>
#         <li>Print <strong>rates_json</strong></li>
#         <li>Print <strong>rates_json['GBP']</strong></li>
#         <li>Cast/convert <strong>rates_json['GBP']</strong> to <strong>float</strong> and assign this float value to variable <strong>gbp</strong> </li>
#         <li>Calculate and print the value of of <strong>200USD</strong> ~ calculation code is shown in the video</li>
#     </ul>
# </span>

# %%
# INSERT GET CODE USING JSON.LOADS TO GET GBP VALUE & CALCULATE 200 USD
rates_json = json.loads(r.text)['rates']
print(rates_json)
print(rates_json['GBP'])
gbp = float(rates_json['GBP'])
print('200USE = ', str(gbp * 200),'GBP')
# Out:
# {'USD': 1, 'AED': 3.67, 'AFN': 85.18, 'ALL': 105.06, 'AMD': 479.06, 'ANG': 1.79, 'AOA': 604.28, 'ARS': 99.63, 'AUD': 1.33, 'AWG': 1.79, 'AZN': 1.71, 'BAM': 1.68, 'BBD': 2, 'BDT': 85.78, 'BGN': 1.68, 'BHD': 0.376, 'BIF': 1991.04, 'BMD': 1, 'BND': 1.35, 'BOB': 6.91, 'BRL': 5.64, 'BSD': 1, 'BTN': 75, 'BWP': 11.24, 'BYN': 2.43, 'BZD': 2, 'CAD': 1.23, 'CDF': 1999.73, 'CHF': 0.918, 'CLP': 816.65, 'CNY': 6.38, 'COP': 3760.49, 'CRC': 630.22, 'CUC': 1, 'CUP': 25, 'CVE': 94.82, 'CZK': 22.16, 'DJF': 177.72, 'DKK': 6.42, 'DOP': 56.47, 'DZD': 137.86, 'EGP': 15.71, 'ERN': 15, 'ETB': 47.56, 'EUR': 0.86, 'FJD': 2.07, 'FKP': 0.726, 'FOK': 6.42, 'GBP': 0.726, 'GEL': 3.14, 'GGP': 0.726, 'GHS': 6.09, 'GIP': 0.726, 'GMD': 52.95, 'GNF': 9757.91, 'GTQ': 7.76, 'GYD': 210.81, 'HKD': 7.77, 'HNL': 24.2, 'HRK': 6.48, 'HTG': 99.97, 'HUF': 315.1, 'IDR': 14108.95, 'ILS': 3.22, 'IMP': 0.726, 'INR': 75, 'IQD': 1470.37, 'IRR': 41989.72, 'ISK': 129.07, 'JMD': 152.9, 'JOD': 0.709, 'JPY': 113.68, 'KES': 111.2, 'KGS': 85.09, 'KHR': 4102.76, 'KID': 1.33, 'KMF': 423.07, 'KRW': 1170.79, 'KWD': 0.3, 'KYD': 0.833, 'KZT': 426.57, 'LAK': 10201.03, 'LBP': 1507.5, 'LKR': 201.16, 'LRD': 162.99, 'LSL': 14.74, 'LYD': 4.59, 'MAD': 9.07, 'MDL': 17.5, 'MGA': 3983.66, 'MKD': 53.21, 'MMK': 1868.38, 'MNT': 2873.71, 'MOP': 8, 'MRU': 36.47, 'MUR': 42.83, 'MVR': 15.46, 'MWK': 817.45, 'MXN': 20.19, 'MYR': 4.15, 'MZN': 64.26, 'NAD': 14.74, 'NGN': 422.38, 'NIO': 35.35, 'NOK': 8.35, 'NPR': 120, 'NZD': 1.4, 'OMR': 0.384, 'PAB': 1, 'PEN': 3.97, 'PGK': 3.52, 'PHP': 50.7, 'PKR': 174.44, 'PLN': 3.97, 'PYG': 6904.06, 'QAR': 3.64, 'RON': 4.25, 'RSD': 101.56, 'RUB': 69.97, 'RWF': 1019.94, 'SAR': 3.75, 'SBD': 7.97, 'SCR': 14.4, 'SDG': 441.27, 'SEK': 8.6, 'SGD': 1.35, 'SHP': 0.726, 'SLL': 10676, 'SOS': 582.58, 'SRD': 21.63, 'SSP': 176.54, 'STN': 21.07, 'SYP': 1686.39, 'SZL': 14.74, 'THB': 33.16, 'TJS': 11.32, 'TMT': 3.51, 'TND': 2.83, 'TOP': 2.23, 'TRY': 9.64, 'TTD': 6.8, 'TVD': 1.33, 'TWD': 27.89, 'TZS': 2309.07, 'UAH': 26.34, 'UGX': 3600.53, 'UYU': 43.92, 'UZS': 10703.01, 'VES': 4.23, 'VND': 22809.32, 'VUV': 110.6, 'WST': 2.55, 'XAF': 564.1, 'XCD': 2.7, 'XDR': 0.706, 'XOF': 564.1, 'XPF': 102.62, 'YER': 251.36, 'ZAR': 14.74, 'ZMW': 17.1}
# 0.726
# 200USE =  145.2 GBP

# %% [markdown]
# ### Using Requests to GET TV Show Information

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>ATTENTION:</strong> The Song Data API now only returns XML (instead of JSON) ~ as per usual, change is constant online :-) <br>
# So, we are going to use a different API to do something similar, but using a different API -- we will use <strong>TV API | TVmaze </strong>[https://api.tvmaze.com/]<br><br>
# For more details, reference the FREE User API information at: https://www.tvmaze.com/api
# </div>

# %% [markdown]
# #### Search for a specific show

# %% [markdown]
# <span style="color:blue">
#     Diverting from the tutorial and using the TVmaze API ...
#     <ul>
#         <li>Use the <strong>Show Search</strong> syntax to search for the show: <strong>Ted Lasso</strong>
#              <ul>
#                  <li>SYNTAX for Search is: /search/shows?q=:query</li>
#                  <li>BASE URL: https://api.tvmaze.com/ </li>
#                  <li>Ted Lasso can be entered as q=ted lasso</li>
#              </ul>
#         <li>Enter the code for a <strong>GET</strong> request specifying <strong>(url, verify=False)</strong></li>
#         <ul>
#             <li>I am having you add <strong>verify=False</strong> to avoid potential SSL Certification errors</li>
#         </ul>
#         <li>Save the response in variable <strong>r</strong></li>
#         <li>Print the response (<strong>r</strong>) value: TEXT</li>
#     </ul>
# </span>

# %%
requests.packages.urllib3.disable_warnings() 
# INSERT GET CODE USING TVMAZE API - SEARCH FOR SHOW 'TED LASSO'
url = 'https://api.tvmaze.com'
search = '/search/shows?'
show = {'q':'ted lasso'}
r = requests.get(url+search, verify = False, params = show)
print(r.text)
# Out:
# [{"score":1.2034441,"show":{"id":44458,"url":"https://www.tvmaze.com/shows/44458/ted-lasso","name":"Ted Lasso","type":"Scripted","language":"English","genres":["Drama","Comedy","Sports"],"status":"Running","runtime":null,"averageRuntime":35,"premiered":"2020-08-14","ended":null,"officialSite":"https://tv.apple.com/show/ted-lasso/umc.cmc.vtoh0mn0xn7t3c643xqonfzy","schedule":{"time":"","days":["Friday"]},"rating":{"average":8.2},"weight":99,"network":null,"webChannel":{"id":310,"name":"Apple TV+","country":null},"dvdCountry":null,"externals":{"tvrage":null,"thetvdb":383203,"imdb":"tt10986410"},"image":{"medium":"https://static.tvmaze.com/uploads/images/medium_portrait/332/830232.jpg","original":"https://static.tvmaze.com/uploads/images/original_untouched/332/830232.jpg"},"summary":"<p><b>Ted Lasso </b>centers on an idealistic — and clueless — all-American football coach hired to manage an English football club — despite having no soccer coaching experience at all.</p>","updated":1633800990,"_links":{"self":{"href":"https://api.tvmaze.com/shows/44458"},"previousepisode":{"href":"https://api.tvmaze.com/episodes/2172942"}}}}]

# %%
# DO NOT MODIFY !!!
# Re-printing the the response in a format that is easier to read
json_data = r.json()
print(json.dumps(json_data, indent=4))
# Out:
# [
#     {
#         "score": 1.2034441,
#         "show": {
#             "id": 44458,
#             "url": "https://www.tvmaze.com/shows/44458/ted-lasso",
#             "name": "Ted Lasso",
#             "type": "Scripted",
#             "language": "English",
#             "genres": [
#                 "Drama",
#                 "Comedy",
#                 "Sports"
#             ],
#             "status": "Running",
#             "runtime": null,
#             "averageRuntime": 35,
#             "premiered": "2020-08-14",
#             "ended": null,
#             "officialSite": "https://tv.apple.com/show/ted-lasso/umc.cmc.vtoh0mn0xn7t3c643xqonfzy",
#             "schedule": {
#                 "time": "",
#                 "days": [
#                     "Friday"
#                 ]
#             },
#             "rating": {
#                 "average": 8.2
#             },
#             "weight": 99,
#             "network": null,
#             "webChannel": {
#                 "id": 310,
#                 "name": "Apple TV+",
#                 "country": null
#             },
#             "dvdCountry": null,
#             "externals": {
#                 "tvrage": null,
#                 "thetvdb": 383203,
#                 "imdb": "tt10986410"
#             },
#             "image": {
#                 "medium": "https://static.tvmaze.com/uploads/images/medium_portrait/332/830232.jpg",
#                 "original": "https://static.tvmaze.com/uploads/images/original_untouched/332/830232.jpg"
#             },
#             "summary": "<p><b>Ted Lasso </b>centers on an idealistic \u2014 and clueless \u2014 all-American football coach hired to manage an English football club \u2014 despite having no soccer coaching experience at all.</p>",
#             "updated": 1633800990,
#             "_links": {
#                 "self": {
#                     "href": "https://api.tvmaze.com/shows/44458"
#                 },
#                 "previousepisode": {
#                     "href": "https://api.tvmaze.com/episodes/2172942"
#                 }
#             }
#         }
#     }
# ]

# %% [markdown]
# #### Extract the show id to use in the next step

# %% [markdown]
# <div class="alert alert-block alert-warning">
# To get data out of a JSON object, which is a combination of lists and dictionaries, just remember:
#     <ul>
#         <li>for <b>lists</b> you need a <b>numerical index</b>, and </li>
#         <li>for <b>key-value pairs</b> you need a <b>text index/key</b>.</li>
#     </ul>
# So if the object looks like this:<br>
#     <b>{"cars":["id":1,"model":"Camry", ... ]}</b> <br>
# you access the model of the first car with <b>text['cars'][0]['model']</b>
# <p>From the previous output, you can see the <strong>json_data</strong> is actually a List containing a Dictionary containing  Dictionaries and/or Lists</p>
#     [ {"score": 1.204098, "show": {"id": 44458, ... "genres": ["Drama","Comedy","Sports"], "status": "Running", ...]
# </div>

# %% [markdown]
# <span style="color:blue">
#     <ul>
#         <li>Get the first (only) list entry, the <strong>show</strong> dictionary entry and the <strong>id</strong> dictionary entry within the show dictionary values</li>
#         <ul>
#             <li><strong>NOTE:</strong> This can all be done with 1 line of code.</li>
#             <li>List entries are referenced using <strong>index</strong> values</li>
#             <li>Dictionary entries are referenced using <strong>key</strong> values</li>
#         </ul>
#         <li>Save the show id in variable <strong>show_id</strong></li>
#         <li>Print <strong>show_id</strong> ~ the value should be <strong>44458</strong></li>
#     </ul>
# </span>

# %%
# INSERT CODE TO GET & PRINT THE 'TED LASSO' SHOW ID -- "id": 44458
show_id = json_data[0]['show']['id']
print(show_id)
# Out:
# 44458

# %% [markdown]
# #### Get the Episode List for this show (using 'show_id' just found)

# %% [markdown]
# <span style="color:blue">
#     <ul>
#         <li>Use the <strong>Show Episode List</strong> syntax to show all the episodes for the <strong>Ted Lasso</strong> show</li>
#              <ul>
#                  <li>SYNTAX for Search is: /shows/:id/episodes</li>
#                  <li>BASE URL: https://api.tvmaze.com/ </li>
#                  <li>/:id/ is the <strong>show_id</strong> value extracted in the previous step</li>
#              </ul>
#         <li>Enter the code for a <strong>GET</strong> request specifying <strong>(url, verify=False)</strong></li>
#         <li>Save the response in variable <strong>r</strong></li>
#         <li>Print the response (<strong>r</strong>) value: TEXT</li>
#     </ul>
# </span>

# %%
# INSERT GET CODE USING TVMAZE API - SHOW EPISODE LIST (id:44458)
url = 'https://api.tvmaze.com'
search = '/shows/'+str(show_id)+'/episodes'
r = requests.get(url+search, verify = False)
print(r.text)
# Out:
# [{"id":1874762,"url":"https://www.tvmaze.com/episodes/1874762/ted-lasso-1x01-pilot","name":"Pilot","season":1,"number":1,"type":"regular","airdate":"2020-08-14","airtime":"","airstamp":"2020-08-14T12:00:00+00:00","runtime":31,"rating":{"average":7.5},"image":{"medium":"https://static.tvmaze.com/uploads/images/medium_landscape/342/856397.jpg","original":"https://static.tvmaze.com/uploads/images/original_untouched/342/856397.jpg"},"summary":"<p>American football coach Ted Lasso is hired by a wealthy divorcée to coach the English soccer team AFC Richmond.</p>","_links":{"self":{"href":"https://api.tvmaze.com/episodes/1874762"}}},{"id":1914171,"url":"https://www.tvmaze.com/episodes/1914171/ted-lasso-1x02-biscuits","name":"Biscuits","season":1,"number":2,"type":"regular","airdate":"2020-08-14","airtime":"","airstamp":"2020-08-14T12:00:00+00:00","runtime":29,"rating":{"average":8.1},"image":{"medium":"https://static.tvmaze.com/uploads/images/medium_landscape/342/856398.jpg","original":"https://static.tvmaze.com/uploads/images/original_untouched/342/856398.jpg"},"summary":"<p>It's Ted's first day of coaching, and fans aren't happy. He makes little headway but remains undeterred as the team plays its first match.</p>","_links":{"self":{"href":"https://api.tvmaze.com/episodes/1914171"}}},{"id":1914172,"url":"https://www.tvmaze.com/episodes/1914172/ted-lasso-1x03-trent-crimm-the-independent","name":"Trent Crimm: The Independent","season":1,"number":3,"type":"regular","airdate":"2020-08-14","airtime":"","airstamp":"2020-08-14T12:00:00+00:00","runtime":30,"rating":{"average":8.2},"image":{"medium":"https://static.tvmaze.com/uploads/images/medium_landscape/342/856399.jpg","original":"https://static.tvmaze.com/uploads/images/original_untouched/342/856399.jpg"},"summary":"<p>To arrange an in-depth exposé, Rebecca pairs cynical journalist Trent Crimm with Ted for a day. Ted and Roy venture into the community.</p>","_links":{"self":{"href":"https://api.tvmaze.com/episodes/1914172"}}},{"id":1914174,"url":"https://www.tvmaze.com/episodes/1914174/ted-lasso-1x04-for-the-children","name":"For the Children","season":1,"number":4,"type":"regular","airdate":"2020-08-21","airtime":"","airstamp":"2020-08-21T12:00:00+00:00","runtime":34,"rating":{"average":8},"image":{"medium":"https://static.tvmaze.com/uploads/images/medium_landscape/268/670419.jpg","original":"https://static.tvmaze.com/uploads/images/original_untouched/268/670419.jpg"},"summary":"<p>Rebecca hosts the team's annual charity benefit, where Ted stages a reconciliation between Roy and Jamie.</p>","_links":{"self":{"href":"https://api.tvmaze.com/episodes/1914174"}}},{"id":1917295,"url":"https://www.tvmaze.com/episodes/1917295/ted-lasso-1x05-tan-lines","name":"Tan Lines","season":1,"number":5,"type":"regular","airdate":"2020-08-28","airtime":"","airstamp":"2020-08-28T12:00:00+00:00","runtime":31,"rating":{"average":8.1},"image":{"medium":"https://static.tvmaze.com/uploads/images/medium_landscape/269/672741.jpg","original":"https://static.tvmaze.com/uploads/images/original_untouched/269/672741.jpg"},"summary":"<p>With his wife and son visiting from America, Ted makes drastic changes to the lineup during a critical match.</p>","_links":{"self":{"href":"https://api.tvmaze.com/episodes/1917295"}}},{"id":1920658,"url":"https://www.tvmaze.com/episodes/1920658/ted-lasso-1x06-two-aces","name":"Two Aces","season":1,"number":6,"type":"regular","airdate":"2020-09-04","airtime":"","airstamp":"2020-09-04T12:00:00+00:00","runtime":32,"rating":{"average":8.1},"image":{"medium":"https://static.tvmaze.com/uploads/images/medium_landscape/270/676813.jpg","original":"https://static.tvmaze.com/uploads/images/original_untouched/270/676813.jpg"},"summary":"<p>When Jamie refuses to train, Ted turns to talented new signing Dani Rojas and the team is struck by an age-old curse.</p>","_links":{"self":{"href":"https://api.tvmaze.com/episodes/1920658"}}},{"id":1924502,"url":"https://www.tvmaze.com/episodes/1924502/ted-la ...

# %%
# DO NOT MODIFY !!!
# Re-printing the the response in a format that is easier to read
json_data = r.json()
print(json.dumps(json_data, indent=4))
# Out:
# [
#     {
#         "id": 1874762,
#         "url": "https://www.tvmaze.com/episodes/1874762/ted-lasso-1x01-pilot",
#         "name": "Pilot",
#         "season": 1,
#         "number": 1,
#         "type": "regular",
#         "airdate": "2020-08-14",
#         "airtime": "",
#         "airstamp": "2020-08-14T12:00:00+00:00",
#         "runtime": 31,
#         "rating": {
#             "average": 7.5
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/342/856397.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/342/856397.jpg"
#         },
#         "summary": "<p>American football coach Ted Lasso is hired by a wealthy divorc\u00e9e to coach the English soccer team AFC Richmond.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/1874762"
#             }
#         }
#     },
#     {
#         "id": 1914171,
#         "url": "https://www.tvmaze.com/episodes/1914171/ted-lasso-1x02-biscuits",
#         "name": "Biscuits",
#         "season": 1,
#         "number": 2,
#         "type": "regular",
#         "airdate": "2020-08-14",
#         "airtime": "",
#         "airstamp": "2020-08-14T12:00:00+00:00",
#         "runtime": 29,
#         "rating": {
#             "average": 8.1
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/342/856398.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/342/856398.jpg"
#         },
#         "summary": "<p>It's Ted's first day of coaching, and fans aren't happy. He makes little headway but remains undeterred as the team plays its first match.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/1914171"
#             }
#         }
#     },
#     {
#         "id": 1914172,
#         "url": "https://www.tvmaze.com/episodes/1914172/ted-lasso-1x03-trent-crimm-the-independent",
#         "name": "Trent Crimm: The Independent",
#         "season": 1,
#         "number": 3,
#         "type": "regular",
#         "airdate": "2020-08-14",
#         "airtime": "",
#         "airstamp": "2020-08-14T12:00:00+00:00",
#         "runtime": 30,
#         "rating": {
#             "average": 8.2
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/342/856399.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/342/856399.jpg"
#         },
#         "summary": "<p>To arrange an in-depth expos\u00e9, Rebecca pairs cynical journalist Trent Crimm with Ted for a day. Ted and Roy venture into the community.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/1914172"
#             }
#         }
#     },
#     {
#         "id": 1914174,
#         "url": "https://www.tvmaze.com/episodes/1914174/ted-lasso-1x04-for-the-children",
#         "name": "For the Children",
#         "season": 1,
#         "number": 4,
#         "type": "regular",
#         "airdate": "2020-08-21",
#         "airtime": "",
#         "airstamp": "2020-08-21T12:00:00+00:00",
#         "runtime": 34,
#         "rating": {
#             "average": 8
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/268/670419.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/268/670419.jpg"
#         },
#         "summary": "<p>Rebecca hosts the team's annual charity benefit, where Ted stages a reconciliation between Roy and Jamie.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/1914174"
#             }
#         }
#     },
#     {
#         "id": 1917295,
#         "url": "https://www.tvmaze.com/episodes/1917295/ted-lasso-1x05-tan-lines",
#         "name": "Tan Lines",
#         "season": 1,
#         "number": 5,
#         "type": "regular",
#         "airdate": "2020-08-28",
#         "airtime": "",
#         "airstamp": "2020-08-28T12:00:00+00:00",
#         "runtime": 31,
#         "rating": {
#             "average": 8.1
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/269/672741.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/269/672741.jpg"
#         },
#         "summary": "<p>With his wife and son visiting from America, Ted makes drastic changes to the lineup during a critical match.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/1917295"
#             }
#         }
#     },
#     {
#         "id": 1920658,
#         "url": "https://www.tvmaze.com/episodes/1920658/ted-lasso-1x06-two-aces",
#         "name": "Two Aces",
#         "season": 1,
#         "number": 6,
#         "type": "regular",
#         "airdate": "2020-09-04",
#         "airtime": "",
#         "airstamp": "2020-09-04T12:00:00+00:00",
#         "runtime": 32,
#         "rating": {
#             "average": 8.1
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/270/676813.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/270/676813.jpg"
#         },
#         "summary": "<p>When Jamie refuses to train, Ted turns to talented new signing Dani Rojas and the team is struck by an age-old curse.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/1920658"
#             }
#         }
#     },
#     {
#         "id": 1924502,
#         "url": "https://www.tvmaze.com/episodes/1924502/ted-lasso-1x07-make-rebecca-great-again",
#         "name": "Make Rebecca Great Again",
#         "season": 1,
#         "number": 7,
#         "type": "regular",
#         "airdate": "2020-09-11",
#         "airtime": "",
#         "airstamp": "2020-09-11T12:00:00+00:00",
#         "runtime": 32,
#         "rating": {
#             "average": 8.3
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/271/678572.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/271/678572.jpg"
#         },
#         "summary": "<p>Rebecca celebrates her first anniversary as a divorc\u00e9e as the team plays a match in Liverpool.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/1924502"
#             }
#         }
#     },
#     {
#         "id": 1928025,
#         "url": "https://www.tvmaze.com/episodes/1928025/ted-lasso-1x08-the-diamond-dogs",
#         "name": "The Diamond Dogs",
#         "season": 1,
#         "number": 8,
#         "type": "regular",
#         "airdate": "2020-09-18",
#         "airtime": "",
#         "airstamp": "2020-09-18T12:00:00+00:00",
#         "runtime": 30,
#         "rating": {
#             "average": 8.1
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/272/681740.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/272/681740.jpg"
#         },
#         "summary": "<p>Ted and Roy are both having relationship problems. Ted consults the Diamond Dogs while Roy lays it on the line with Keeley.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/1928025"
#             }
#         }
#     },
#     {
#         "id": 1931405,
#         "url": "https://www.tvmaze.com/episodes/1931405/ted-lasso-1x09-all-apologies",
#         "name": "All Apologies",
#         "season": 1,
#         "number": 9,
#         "type": "regular",
#         "airdate": "2020-09-25",
#         "airtime": "",
#         "airstamp": "2020-09-25T12:00:00+00:00",
#         "runtime": 31,
#         "rating": {
#             "average": 8.2
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/273/684734.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/273/684734.jpg"
#         },
#         "summary": "<p>After a series of mistakes on the pitch, pressure mounts to bench Roy. Rebecca finally reveals the truth to Ted.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/1931405"
#             }
#         }
#     },
#     {
#         "id": 1937602,
#         "url": "https://www.tvmaze.com/episodes/1937602/ted-lasso-1x10-the-hope-that-kills-you",
#         "name": "The Hope That Kills You",
#         "season": 1,
#         "number": 10,
#         "type": "regular",
#         "airdate": "2020-10-02",
#         "airtime": "",
#         "airstamp": "2020-10-02T12:00:00+00:00",
#         "runtime": 34,
#         "rating": {
#             "average": 8.1
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/275/687809.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/275/687809.jpg"
#         },
#         "summary": "<p>Richmond plays a climactic match that will determine the fates of Ted and his club.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/1937602"
#             }
#         }
#     },
#     {
#         "id": 2075166,
#         "url": "https://www.tvmaze.com/episodes/2075166/ted-lasso-2x01-goodbye-earl",
#         "name": "Goodbye Earl",
#         "season": 2,
#         "number": 1,
#         "type": "regular",
#         "airdate": "2021-07-23",
#         "airtime": "",
#         "airstamp": "2021-07-23T12:00:00+00:00",
#         "runtime": 34,
#         "rating": {
#             "average": 7.7
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/341/852868.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/341/852868.jpg"
#         },
#         "summary": "<p>AFC Richmond brings in a sports psychologist to help the team overcome their unprecedented seven game tie-streak.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/2075166"
#             }
#         }
#     },
#     {
#         "id": 2132225,
#         "url": "https://www.tvmaze.com/episodes/2132225/ted-lasso-2x02-lavender",
#         "name": "Lavender",
#         "season": 2,
#         "number": 2,
#         "type": "regular",
#         "airdate": "2021-07-30",
#         "airtime": "",
#         "airstamp": "2021-07-30T12:00:00+00:00",
#         "runtime": 33,
#         "rating": {
#             "average": 7.8
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/341/852869.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/341/852869.jpg"
#         },
#         "summary": "<p>Ted is surprised by the reappearance of a familiar face. Roy tries out a new gig.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/2132225"
#             }
#         }
#     },
#     {
#         "id": 2138281,
#         "url": "https://www.tvmaze.com/episodes/2138281/ted-lasso-2x03-do-the-right-est-thing",
#         "name": "Do the Right-est Thing",
#         "season": 2,
#         "number": 3,
#         "type": "regular",
#         "airdate": "2021-08-06",
#         "airtime": "",
#         "airstamp": "2021-08-06T12:00:00+00:00",
#         "runtime": 36,
#         "rating": {
#             "average": 8.1
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/344/862256.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/344/862256.jpg"
#         },
#         "summary": "<p>Rebecca has a special visitor shadow her at work. A player's return is not welcomed by the team.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/2138281"
#             }
#         }
#     },
#     {
#         "id": 2142664,
#         "url": "https://www.tvmaze.com/episodes/2142664/ted-lasso-2x04-carol-of-the-bells",
#         "name": "Carol of the Bells",
#         "season": 2,
#         "number": 4,
#         "type": "regular",
#         "airdate": "2021-08-13",
#         "airtime": "",
#         "airstamp": "2021-08-13T12:00:00+00:00",
#         "runtime": 30,
#         "rating": {
#             "average": 8.6
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/346/866045.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/346/866045.jpg"
#         },
#         "summary": "<p>It's Christmas in Richmond. Rebecca enlists Ted for a secret mission, Roy and Keeley search for a miracle, and the Higginses open up their home.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/2142664"
#             }
#         }
#     },
#     {
#         "id": 2147114,
#         "url": "https://www.tvmaze.com/episodes/2147114/ted-lasso-2x05-rainbow",
#         "name": "Rainbow",
#         "season": 2,
#         "number": 5,
#         "type": "regular",
#         "airdate": "2021-08-20",
#         "airtime": "",
#         "airstamp": "2021-08-20T12:00:00+00:00",
#         "runtime": 38,
#         "rating": {
#             "average": 8.2
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/348/871312.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/348/871312.jpg"
#         },
#         "summary": "<p>Nate learns how to be assertive from Keeley and Rebecca. Ted asks Roy for a favor.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/2147114"
#             }
#         }
#     },
#     {
#         "id": 2151080,
#         "url": "https://www.tvmaze.com/episodes/2151080/ted-lasso-2x06-the-signal",
#         "name": "The Signal",
#         "season": 2,
#         "number": 6,
#         "type": "regular",
#         "airdate": "2021-08-27",
#         "airtime": "",
#         "airstamp": "2021-08-27T12:00:00+00:00",
#         "runtime": 35,
#         "rating": {
#             "average": 7.9
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/350/875535.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/350/875535.jpg"
#         },
#         "summary": "<p>Ted is fired up that the new team dynamic seems to be working. But will they have a chance in the semifinal?</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/2151080"
#             }
#         }
#     },
#     {
#         "id": 2156168,
#         "url": "https://www.tvmaze.com/episodes/2156168/ted-lasso-2x07-headspace",
#         "name": "Headspace",
#         "season": 2,
#         "number": 7,
#         "type": "regular",
#         "airdate": "2021-09-03",
#         "airtime": "",
#         "airstamp": "2021-09-03T12:00:00+00:00",
#         "runtime": 35,
#         "rating": {
#             "average": 7.2
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/352/880559.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/352/880559.jpg"
#         },
#         "summary": "<p>With things turning around for Richmond, it's time for everyone to work on their issues\u2014like Ted's discomfort, Nate's confidence, and Roy's attention.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/2156168"
#             }
#         }
#     },
#     {
#         "id": 2161174,
#         "url": "https://www.tvmaze.com/episodes/2161174/ted-lasso-2x08-man-city",
#         "name": "Man City",
#         "season": 2,
#         "number": 8,
#         "type": "regular",
#         "airdate": "2021-09-10",
#         "airtime": "",
#         "airstamp": "2021-09-10T12:00:00+00:00",
#         "runtime": 45,
#         "rating": {
#             "average": 8
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/353/884734.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/353/884734.jpg"
#         },
#         "summary": "<p>Ted and Dr. Sarah realize they might have to meet each other halfway. Tensions are high as the team prepares for the semifinal.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/2161174"
#             }
#         }
#     },
#     {
#         "id": 2166305,
#         "url": "https://www.tvmaze.com/episodes/2166305/ted-lasso-2x09-beard-after-hours",
#         "name": "Beard After Hours",
#         "season": 2,
#         "number": 9,
#         "type": "regular",
#         "airdate": "2021-09-17",
#         "airtime": "",
#         "airstamp": "2021-09-17T12:00:00+00:00",
#         "runtime": 43,
#         "rating": {
#             "average": 6.8
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/356/890404.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/356/890404.jpg"
#         },
#         "summary": "<p>After the semifinal, Beard sets out on an all-night odyssey through London in an effort to collect his thoughts.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/2166305"
#             }
#         }
#     },
#     {
#         "id": 2172163,
#         "url": "https://www.tvmaze.com/episodes/2172163/ted-lasso-2x10-no-weddings-and-a-funeral",
#         "name": "No Weddings and a Funeral",
#         "season": 2,
#         "number": 10,
#         "type": "regular",
#         "airdate": "2021-09-24",
#         "airtime": "",
#         "airstamp": "2021-09-24T12:00:00+00:00",
#         "runtime": 46,
#         "rating": {
#             "average": 7.6
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/357/894799.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/357/894799.jpg"
#         },
#         "summary": "<p>Rebecca is stunned by a sudden loss. The team rallies to show their support, but Ted finds himself grappling with a piece of his past.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/2172163"
#             }
#         }
#     },
#     {
#         "id": 2172941,
#         "url": "https://www.tvmaze.com/episodes/2172941/ted-lasso-2x11-midnight-train-to-royston",
#         "name": "Midnight Train to Royston",
#         "season": 2,
#         "number": 11,
#         "type": "regular",
#         "airdate": "2021-10-01",
#         "airtime": "",
#         "airstamp": "2021-10-01T12:00:00+00:00",
#         "runtime": 42,
#         "rating": {
#             "average": 7.7
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/360/900284.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/360/900284.jpg"
#         },
#         "summary": "<p>A billionaire football enthusiast from Ghana makes Sam an unbelievable offer. Ted plans something special for Dr. Sharon's last day with the team.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/2172941"
#             }
#         }
#     },
#     {
#         "id": 2172942,
#         "url": "https://www.tvmaze.com/episodes/2172942/ted-lasso-2x12-inverting-the-pyramid-of-success",
#         "name": "Inverting the Pyramid of Success",
#         "season": 2,
#         "number": 12,
#         "type": "regular",
#         "airdate": "2021-10-08",
#         "airtime": "",
#         "airstamp": "2021-10-08T12:00:00+00:00",
#         "runtime": 49,
#         "rating": {
#             "average": 8
#         },
#         "image": {
#             "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/362/905367.jpg",
#             "original": "https://static.tvmaze.com/uploads/images/original_untouched/362/905367.jpg"
#         },
#         "summary": "<p>Richmond gets their final chance to win promotion as Ted deals with the fallout of Trent Crimm's painfully honest expos\u00e9.</p>",
#         "_links": {
#             "self": {
#                 "href": "https://api.tvmaze.com/episodes/2172942"
#             }
#         }
#     }
# ]

# %% [markdown]
# #### Get Episode Information for a specific episode of this show

# %% [markdown]
# <span style="color:blue">
#     <ul>
#         <li>Use the <strong>Episode by number</strong> syntax to show the information for a specific episode</li>
#              <ul>
#                  <li>SYNTAX for Search is: /shows/:id/episodebynumber?season=:season&amp;number=:number</li>
#                  <li>BASE URL: https://api.tvmaze.com/ </li>
#                  <li>Re-use the <strong>show_id</strong> value you got earlier</li>
#                  <li>Get the episode information for 'season=1&amp;number=8 (Season 1, Episode 8) </li>
#              </ul>
#         <li>Enter the code for a <strong>GET</strong> request specifying <strong>(url, verify=False)</strong></li>
#         <li>Save the response in variable <strong>r</strong></li>
#         <li>Print the response (<strong>r</strong>) value: TEXT</li>
#     </ul>
# </span>

# %%
# INSERT GET CODE USING TVMAZE API - SHOW EPISODE BY NUMBER (season=1,episode=8)
url = 'https://api.tvmaze.com'
search = '/shows/'+str(show_id)+'/episodebynumber'
epi_info = {'season':1, 'number':8}
r = requests.get(url+search, verify = False, params=epi_info)
print(r.url)
print(r.text)
# Out:
# https://api.tvmaze.com/shows/44458/episodebynumber?season=1&number=8
# {"id":1928025,"url":"https://www.tvmaze.com/episodes/1928025/ted-lasso-1x08-the-diamond-dogs","name":"The Diamond Dogs","season":1,"number":8,"type":"regular","airdate":"2020-09-18","airtime":"","airstamp":"2020-09-18T12:00:00+00:00","runtime":30,"rating":{"average":8.1},"image":{"medium":"https://static.tvmaze.com/uploads/images/medium_landscape/272/681740.jpg","original":"https://static.tvmaze.com/uploads/images/original_untouched/272/681740.jpg"},"summary":"<p>Ted and Roy are both having relationship problems. Ted consults the Diamond Dogs while Roy lays it on the line with Keeley.</p>","_links":{"self":{"href":"https://api.tvmaze.com/episodes/1928025"}}}

# %%
# DO NOT MODIFY !!!
# Re-printing the the response in a format that is easier to read
json_data = r.json()
print(json.dumps(json_data, indent=4))
# Out:
# {
#     "id": 1928025,
#     "url": "https://www.tvmaze.com/episodes/1928025/ted-lasso-1x08-the-diamond-dogs",
#     "name": "The Diamond Dogs",
#     "season": 1,
#     "number": 8,
#     "type": "regular",
#     "airdate": "2020-09-18",
#     "airtime": "",
#     "airstamp": "2020-09-18T12:00:00+00:00",
#     "runtime": 30,
#     "rating": {
#         "average": 8.1
#     },
#     "image": {
#         "medium": "https://static.tvmaze.com/uploads/images/medium_landscape/272/681740.jpg",
#         "original": "https://static.tvmaze.com/uploads/images/original_untouched/272/681740.jpg"
#     },
#     "summary": "<p>Ted and Roy are both having relationship problems. Ted consults the Diamond Dogs while Roy lays it on the line with Keeley.</p>",
#     "_links": {
#         "self": {
#             "href": "https://api.tvmaze.com/episodes/1928025"
#         }
#     }
# }

# %% [markdown]
# #### Extract specific values from the episode data

# %% [markdown]
# <span style="color:blue">
# Insert the code from the tutorial to use <strong>json.loads</strong> to convert the text string into a Python dictionary
# <ul>
#     <li>Use <strong>json.loads</strong> to convert the text string into a Python dictionary</li>
#    <ul>
#        <li>referencing the <strong>text</strong> portion of the response object get the <strong>name, airdate, runtime and summary</strong> values</li>
#        <li>assign the results to variable <strong>episode_data</strong></li>
#    </ul>
#    <li> Print each of the values using a separate print(...) statement on a separate line</li>
# </ul>
# </span>

# %%
# INSERT GET CODE USING JSON.LOADS TO GET THE NAME, AIRDATE, RUNTIME and SUMMARY
episode_json = json.loads(r.text)
episode_data = [episode_json['name'], 
                episode_json['airdate'],
                episode_json['runtime'],
                episode_json['summary']]
print('Name:' , episode_data[0])
print('Airdate:' , episode_data[1])
print('Runtime:' , episode_data[2])
print('Summary:' , episode_data[3])
# Out:
# Name: The Diamond Dogs
# Airdate: 2020-09-18
# Runtime: 30
# Summary: <p>Ted and Roy are both having relationship problems. Ted consults the Diamond Dogs while Roy lays it on the line with Keeley.</p>

# %% [markdown]
# # PART B (90 points)

# %% [markdown]
# ### Penguin Random House - Business Services.biz (REST SERVICES APIs)
# ##### URL: http://www.penguinrandomhouse.biz/webservices/rest/

# %%
import requests
import json

# %% [markdown]
# ### Search for Authors -- Use the GET /resources/authors API  (18 points)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     The <strong>Method Details</strong> for the <strong>GET /resources/authors</strong> API can be found at the following link. <strong>HINT:</strong> To see an example of the URL syntax for this request, take a look at the <strong>USAGE</strong> section and click on <strong>expand source</strong> under <strong>bash</strong>.
#
#     http://www.penguinrandomhouse.biz/webservices/rest/#authors
# </div>

# %% [markdown]
# #### Search for Author: Dan Brown

# %% [markdown]
# <span style="color:blue">
#     <ul>
#         <li>Use the <strong>Penguin Random House API</strong> to do a <strong>GET</strong> request</li>
#         <li>Include <strong>search</strong> for author <strong>Dan Brown</strong></li>
#         <li>Include <strong>headers</strong> value of <strong>'Accept': 'application/json'</strong></li>
#         <li>Print the Response <strong>text</strong></li>
#     </ul>
# </span>

# %%
# INSERT GET WITH SEARCH FOR DAN BROWN
payload = {'lastName':'Brown', 'firstName':'Dan'}
url = 'https://reststop.randomhouse.com/resources/authors'
headers = {'Accept':'application/json'}
r = requests.get(url, headers = headers, verify = False, params=payload)
print(r.text)
# Out:
# {"@uri":"https://reststop.randomhouse.com/resources/authors?lastName=Brown&firstName=Dan","author":[{"@uri":"https://reststop.randomhouse.com/resources/authors/3446","approved":"X","authordisplay":"Dan Brown","authorfirst":"Dan","authorfirstlc":"dan","authorid":"3446","authorlast":"Brown","authorlastfirst":"BROWN, DAN","authorlastlc":"brown","titles":{"isbn":[{"@contributortype":"A","$":"9780307277671"},{"@contributortype":"A","$":"9780307448057"},{"@contributortype":"A","$":"9780307474278"},{"@contributortype":"A","$":"9780307704061"},{"@contributortype":"A","$":"9780307736932"},{"@contributortype":"A","$":"9780307736956"},{"@contributortype":"A","$":"9780307741905"},{"@contributortype":"A","$":"9780307879257"},{"@contributortype":"A","$":"9780307950680"},{"@contributortype":"A","$":"9780375434549"},{"@contributortype":"A","$":"9780385504201"},{"@contributortype":"A","$":"9780385504218"},{"@contributortype":"A","$":"9780385504225"},{"@contributortype":"A","$":"9780385513753"},{"@contributortype":"A","$":"9780385514231"},{"@contributortype":"A","$":"9780385533133"},{"@contributortype":"A","$":"9780385534505"},{"@contributortype":"A","$":"9780385537858"},{"@contributortype":"A","$":"9780385537865"},{"@contributortype":"A","$":"9780385539852"},{"@contributortype":"A","$":"9780385539920"},{"@contributortype":"A","$":"9780385539944"},{"@contributortype":"A","$":"9780385542692"},{"@contributortype":"A","$":"9780525563693"},{"@contributortype":"A","$":"9780525563709"},{"@contributortype":"A","$":"9780525565857"},{"@contributortype":"A","$":"9780525565864"},{"@contributortype":"A","$":"9780525565871"},{"@contributortype":"A","$":"9780593123843"},{"@contributortype":"A","$":"9780593123850"},{"@contributortype":"A","$":"9780739309575"},{"@contributortype":"A","$":"9780739319185"},{"@contributortype":"A","$":"9780739319277"},{"@contributortype":"A","$":"9780739319291"},{"@contributortype":"A","$":"9780739319307"},{"@contributortype":"A","$":"9780739326749"},{"@contributortype":"A","$":"9780739340653"},{"@contributortype":"A","$":"9780739353127"},{"@contributortype":"A","$":"9780767926034"},{"@contributortype":"A","$":"9780804121064"},{"@contributortype":"A","$":"9780804128773"},{"@contributortype":"A","$":"9780804128797"},{"@contributortype":"A","$":"9780804147989"},{"@contributortype":"A","$":"9780804165747"},{"@contributortype":"A","$":"9780804171540"},{"@contributortype":"A","$":"9780804172264"},{"@contributortype":"A","$":"9781400079148"},{"@contributortype":"A","$":"9781400079155"},{"@contributortype":"A","$":"9781400079162"},{"@contributortype":"A","$":"9781415934777"},{"@contributortype":"A","$":"9781524715823"},{"@contributortype":"A","$":"9781524715847"},{"@contributortype":"A","$":"9781524722470"},{"@contributortype":"A","$":"9781524734879"},{"@contributortype":"A","$":"9781524734893"},{"@contributortype":"A","$":"9781524779122"},{"@contributortype":"A","$":"9781984833006"},{"@contributortype":"A","$":"9781984833525"},{"@contributortype":"A","$":"9781984833532"}]},"lastinitial":"b","photocredit":"Dan Courter","photodate":"2017","spotlight":"<b> <b>Dan Brown</b>&#160;</b>is the author of numerous #1 international bestsellers, including&#160;<i>The Da Vinci Code,&#160;<i>Origin,</i> Inferno</i>,&#160;<i>The Lost Symbol</i>,<i>&#160;Angels &amp; Demons</i>,&#160;<i>Deception Point,</i>&#160;and&#160;<i>Digital Fortress</i>.<br><b><br>Dan Brown&#160;</b>es el autor de m&uacute;ltiples bestsellers internacionales<i>&#160;</i>incluyendo&#160;<i>El c&oacute;digo Da Vinci</i>,&#160;<i>Inferno</i>,<i>&#160;El s&iacute;mbolo perdido</i>,&#160;<i>&Aacute;ngeles y demonios, La fortaleza digital&#160;</i>y<i>&#160;La conspiraci&oacute;n</i>. Sus novelas han sido traducidas a 56 idiomas alrededor del mundo, con mas de 200 millones de copias actualmente impresas. En 2005, fue nombrado una de las 100 personas mas influenciales del mundo por la revista&#160;<i>Time.</i>&#160;Vive en Nueva Inglaterra con su esposa.","works":{"works":["19306","1 ...

# %% [markdown]
# #### Use "Pretty JSON" formatting to print the JSON for easier reading

# %% [markdown]
# <span style="color:blue">
#     <ul>
#         <li>Use <strong>json.loads</strong> to convert the text string into a Python dict</li>
#         <li>Save the value in variable <strong>text_json</strong></li>
#         <li>Print <strong>text_json</strong> using <strong>json.dumps</strong> with <strong>indent=4, sort_keys=True</strong> to make it easier to read (see Lab8)</li>
#     </ul>
# </span>

# %%
# INSERT JSON.LOADS and JSON.DUMPS CODE (Ref: Pretty JSON print)
text_json = json.loads(r.text)
print(json.dumps(text_json, indent=4))
# Out:
# {
#     "@uri": "https://reststop.randomhouse.com/resources/authors?lastName=Brown&firstName=Dan",
#     "author": [
#         {
#             "@uri": "https://reststop.randomhouse.com/resources/authors/3446",
#             "approved": "X",
#             "authordisplay": "Dan Brown",
#             "authorfirst": "Dan",
#             "authorfirstlc": "dan",
#             "authorid": "3446",
#             "authorlast": "Brown",
#             "authorlastfirst": "BROWN, DAN",
#             "authorlastlc": "brown",
#             "titles": {
#                 "isbn": [
#                     {
#                         "@contributortype": "A",
#                         "$": "9780307277671"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780307448057"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780307474278"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780307704061"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780307736932"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780307736956"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780307741905"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780307879257"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780307950680"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780375434549"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780385504201"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780385504218"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780385504225"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780385513753"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780385514231"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780385533133"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780385534505"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780385537858"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780385537865"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780385539852"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780385539920"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780385539944"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780385542692"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780525563693"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780525563709"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780525565857"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780525565864"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780525565871"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780593123843"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780593123850"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780739309575"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780739319185"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780739319277"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780739319291"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780739319307"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780739326749"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780739340653"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780739353127"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780767926034"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780804121064"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780804128773"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780804128797"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780804147989"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780804165747"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780804171540"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780804172264"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9781400079148"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9781400079155"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9781400079162"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9781415934777"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9781524715823"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9781524715847"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9781524722470"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9781524734879"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9781524734893"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9781524779122"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9781984833006"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9781984833525"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9781984833532"
#                     }
#                 ]
#             },
#             "lastinitial": "b",
#             "photocredit": "Dan Courter",
#             "photodate": "2017",
#             "spotlight": "<b> <b>Dan Brown</b>&#160;</b>is the author of numerous #1 international bestsellers, including&#160;<i>The Da Vinci Code,&#160;<i>Origin,</i> Inferno</i>,&#160;<i>The Lost Symbol</i>,<i>&#160;Angels &amp; Demons</i>,&#160;<i>Deception Point,</i>&#160;and&#160;<i>Digital Fortress</i>.<br><b><br>Dan Brown&#160;</b>es el autor de m&uacute;ltiples bestsellers internacionales<i>&#160;</i>incluyendo&#160;<i>El c&oacute;digo Da Vinci</i>,&#160;<i>Inferno</i>,<i>&#160;El s&iacute;mbolo perdido</i>,&#160;<i>&Aacute;ngeles y demonios, La fortaleza digital&#160;</i>y<i>&#160;La conspiraci&oacute;n</i>. Sus novelas han sido traducidas a 56 idiomas alrededor del mundo, con mas de 200 millones de copias actualmente impresas. En 2005, fue nombrado una de las 100 personas mas influenciales del mundo por la revista&#160;<i>Time.</i>&#160;Vive en Nueva Inglaterra con su esposa.",
#             "works": {
#                 "works": [
#                     "19306",
#                     "19308",
#                     "19309",
#                     "19310",
#                     "19311",
#                     "19312",
#                     "19314",
#                     "68980",
#                     "203096",
#                     "204509",
#                     "227777",
#                     "228145",
#                     "248567",
#                     "249100",
#                     "300240",
#                     "549111",
#                     "549656",
#                     "554852",
#                     "555126",
#                     "612065"
#                 ]
#             }
#         },
#         {
#             "@uri": "https://reststop.randomhouse.com/resources/authors/224942",
#             "approved": "X",
#             "authordisplay": "Dan Brown",
#             "authorfirst": "Dan",
#             "authorfirstlc": "dan",
#             "authorid": "224942",
#             "authorlast": "Brown",
#             "authorlastfirst": "BROWN, DAN",
#             "authorlastlc": "brown",
#             "titles": null,
#             "lastinitial": "b",
#             "works": {
#                 "works": "243657"
#             }
#         },
#         {
#             "@uri": "https://reststop.randomhouse.com/resources/authors/2182290",
#             "approved": "X",
#             "authordisplay": "Dan Brown",
#             "authorfirst": "Dan",
#             "authorfirstlc": "dan",
#             "authorid": "2182290",
#             "authorlast": "Brown",
#             "authorlastfirst": "BROWN, DAN",
#             "authorlastlc": "brown",
#             "titles": {
#                 "isbn": [
#                     {
#                         "@contributortype": "I",
#                         "$": "9780823416332"
#                     },
#                     {
#                         "@contributortype": "I",
#                         "$": "9780823416653"
#                     }
#                 ]
#             },
#             "lastinitial": "b",
#             "works": {
#                 "works": [
#                     "589567",
#                     "589587"
#                 ]
#             }
#         },
#         {
#             "@uri": "https://reststop.randomhouse.com/resources/authors/2256087",
#             "approved": "X",
#             "authordisplay": "Dan Brown",
#             "authorfirst": "Dan",
#             "authorfirstlc": "dan",
#             "authorid": "2256087",
#             "authorlast": "Brown",
#             "authorlastfirst": "BROWN, DAN",
#             "authorlastlc": "brown",
#             "titles": {
#                 "isbn": [
#                     {
#                         "@contributortype": "A",
#                         "$": "9780345806482"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780345806499"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780525434290"
#                     },
#                     {
#                         "@contributortype": "A",
#                         "$": "9780525563716"
#                     }
#                 ]
#             },
#             "lastinitial": "b",
#             "works": {
#                 "works": [
#                     "228145",
#                     "555126"
#                 ]
#             }
#         }
#     ]
# }

# %% [markdown]
# #### Get the Author ID value from json_text (Get the 1st one you see -- "authorid": "3446")

# %% [markdown]
# <span style="color:blue">
#     <ul>
#         <li>Get the <strong>authorid</strong> value </li>
#         <li>Save the <strong>authorid</strong> in a variable named <strong>author_id</strong>
#         <li>Print the <strong>author_id</strong> -- format the output as follows "AUTHOR ID: xxxx"</li>
#     </ul>
# </span>

# %%
# INSERT GET & PRINT OF JSON 'authorid' VALUE -- "authorid": "3446"
author_id = text_json['author'][0]['authorid']
print('AUTHOR ID: ',author_id)
# Out:
# AUTHOR ID:  3446

# %% [markdown]
# ### Get details for a specific author -- Use the GET /resources/authors/AUTHORID API  (18 Points)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     The <strong>Method Details</strong> for the <strong>GET /resources/authors/AUTHORID</strong> API can be found at the following link. <strong>HINT:</strong> To see an example of the URL syntax for this request, take a look at the <strong>USAGE</strong> section and click on <strong>expand source</strong> under <strong>bash</strong>.
#
#     http://www.penguinrandomhouse.biz/webservices/rest/#author
# </div>

# %% [markdown]
# <span style="color:blue">
#     <ul>
#         <li>Use the <strong>Penguin Random House API</strong> to do a <strong>GET</strong> request using the <strong>author_id</strong> value/variable found in the previous step. </li>
#         <li>Include <strong>headers</strong> value of <strong>'Accept': 'application/json'</strong></li>
#         <li>Print the Response <strong>text</strong></li>
#     </ul>
# </span>

# %%
# INSERT GET SPECIFIC AUTHOR USING AUTHORID API
payload = {'authorid':author_id}
url = 'https://reststop.randomhouse.com/resources/authors'
headers = {'Accept':'application/json'}
r = requests.get(url, headers = headers, verify = False, params=payload)
print(r.text)
# Out:
# {"@uri":"https://reststop.randomhouse.com/resources/authors?authorid=3446","author":{"@uri":"https://reststop.randomhouse.com/resources/authors/3446","approved":"X","authordisplay":"Dan Brown","authorfirst":"Dan","authorfirstlc":"dan","authorid":"3446","authorlast":"Brown","authorlastfirst":"BROWN, DAN","authorlastlc":"brown","titles":{"isbn":[{"@contributortype":"A","$":"9780307277671"},{"@contributortype":"A","$":"9780307448057"},{"@contributortype":"A","$":"9780307474278"},{"@contributortype":"A","$":"9780307704061"},{"@contributortype":"A","$":"9780307736932"},{"@contributortype":"A","$":"9780307736956"},{"@contributortype":"A","$":"9780307741905"},{"@contributortype":"A","$":"9780307879257"},{"@contributortype":"A","$":"9780307950680"},{"@contributortype":"A","$":"9780375434549"},{"@contributortype":"A","$":"9780385504201"},{"@contributortype":"A","$":"9780385504218"},{"@contributortype":"A","$":"9780385504225"},{"@contributortype":"A","$":"9780385513753"},{"@contributortype":"A","$":"9780385514231"},{"@contributortype":"A","$":"9780385533133"},{"@contributortype":"A","$":"9780385534505"},{"@contributortype":"A","$":"9780385537858"},{"@contributortype":"A","$":"9780385537865"},{"@contributortype":"A","$":"9780385539852"},{"@contributortype":"A","$":"9780385539920"},{"@contributortype":"A","$":"9780385539944"},{"@contributortype":"A","$":"9780385542692"},{"@contributortype":"A","$":"9780525563693"},{"@contributortype":"A","$":"9780525563709"},{"@contributortype":"A","$":"9780525565857"},{"@contributortype":"A","$":"9780525565864"},{"@contributortype":"A","$":"9780525565871"},{"@contributortype":"A","$":"9780593123843"},{"@contributortype":"A","$":"9780593123850"},{"@contributortype":"A","$":"9780739309575"},{"@contributortype":"A","$":"9780739319185"},{"@contributortype":"A","$":"9780739319277"},{"@contributortype":"A","$":"9780739319291"},{"@contributortype":"A","$":"9780739319307"},{"@contributortype":"A","$":"9780739326749"},{"@contributortype":"A","$":"9780739340653"},{"@contributortype":"A","$":"9780739353127"},{"@contributortype":"A","$":"9780767926034"},{"@contributortype":"A","$":"9780804121064"},{"@contributortype":"A","$":"9780804128773"},{"@contributortype":"A","$":"9780804128797"},{"@contributortype":"A","$":"9780804147989"},{"@contributortype":"A","$":"9780804165747"},{"@contributortype":"A","$":"9780804171540"},{"@contributortype":"A","$":"9780804172264"},{"@contributortype":"A","$":"9781400079148"},{"@contributortype":"A","$":"9781400079155"},{"@contributortype":"A","$":"9781400079162"},{"@contributortype":"A","$":"9781415934777"},{"@contributortype":"A","$":"9781524715823"},{"@contributortype":"A","$":"9781524715847"},{"@contributortype":"A","$":"9781524722470"},{"@contributortype":"A","$":"9781524734879"},{"@contributortype":"A","$":"9781524734893"},{"@contributortype":"A","$":"9781524779122"},{"@contributortype":"A","$":"9781984833006"},{"@contributortype":"A","$":"9781984833525"},{"@contributortype":"A","$":"9781984833532"}]},"lastinitial":"b","photocredit":"Dan Courter","photodate":"2017","spotlight":"<b> <b>Dan Brown</b>&#160;</b>is the author of numerous #1 international bestsellers, including&#160;<i>The Da Vinci Code,&#160;<i>Origin,</i> Inferno</i>,&#160;<i>The Lost Symbol</i>,<i>&#160;Angels &amp; Demons</i>,&#160;<i>Deception Point,</i>&#160;and&#160;<i>Digital Fortress</i>.<br><b><br>Dan Brown&#160;</b>es el autor de m&uacute;ltiples bestsellers internacionales<i>&#160;</i>incluyendo&#160;<i>El c&oacute;digo Da Vinci</i>,&#160;<i>Inferno</i>,<i>&#160;El s&iacute;mbolo perdido</i>,&#160;<i>&Aacute;ngeles y demonios, La fortaleza digital&#160;</i>y<i>&#160;La conspiraci&oacute;n</i>. Sus novelas han sido traducidas a 56 idiomas alrededor del mundo, con mas de 200 millones de copias actualmente impresas. En 2005, fue nombrado una de las 100 personas mas influenciales del mundo por la revista&#160;<i>Time.</i>&#160;Vive en Nueva Inglaterra con su esposa.","works":{"works":["19306","19308","19309","1 ...

# %% [markdown]
# #### Use "Pretty JSON" formatting to print the JSON for easier reading

# %% [markdown]
# <span style="color:blue">
#     <ul>
#         <li>Use <strong>json.loads</strong> to convert the text string into a Python dict</li>
#         <li>Save the value in variable <strong>text_json</strong></li>
#         <li>Print <strong>text_json</strong> using <strong>json.dumps</strong> with <strong>indent=4, sort_keys=True</strong> to make it easier to read (see Lab8)</li>
#     </ul>
# </span>

# %%
# INSERT JSON.LOADS and JSON.DUMPS CODE (Ref: Pretty JSON print)
text_json = json.loads(r.text)
print(json.dumps(text_json, indent=4))
# Out:
# {
#     "@uri": "https://reststop.randomhouse.com/resources/authors?authorid=3446",
#     "author": {
#         "@uri": "https://reststop.randomhouse.com/resources/authors/3446",
#         "approved": "X",
#         "authordisplay": "Dan Brown",
#         "authorfirst": "Dan",
#         "authorfirstlc": "dan",
#         "authorid": "3446",
#         "authorlast": "Brown",
#         "authorlastfirst": "BROWN, DAN",
#         "authorlastlc": "brown",
#         "titles": {
#             "isbn": [
#                 {
#                     "@contributortype": "A",
#                     "$": "9780307277671"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780307448057"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780307474278"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780307704061"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780307736932"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780307736956"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780307741905"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780307879257"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780307950680"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780375434549"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780385504201"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780385504218"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780385504225"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780385513753"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780385514231"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780385533133"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780385534505"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780385537858"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780385537865"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780385539852"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780385539920"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780385539944"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780385542692"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780525563693"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780525563709"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780525565857"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780525565864"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780525565871"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780593123843"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780593123850"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780739309575"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780739319185"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780739319277"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780739319291"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780739319307"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780739326749"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780739340653"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780739353127"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780767926034"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780804121064"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780804128773"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780804128797"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780804147989"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780804165747"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780804171540"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9780804172264"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9781400079148"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9781400079155"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9781400079162"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9781415934777"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9781524715823"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9781524715847"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9781524722470"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9781524734879"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9781524734893"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9781524779122"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9781984833006"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9781984833525"
#                 },
#                 {
#                     "@contributortype": "A",
#                     "$": "9781984833532"
#                 }
#             ]
#         },
#         "lastinitial": "b",
#         "photocredit": "Dan Courter",
#         "photodate": "2017",
#         "spotlight": "<b> <b>Dan Brown</b>&#160;</b>is the author of numerous #1 international bestsellers, including&#160;<i>The Da Vinci Code,&#160;<i>Origin,</i> Inferno</i>,&#160;<i>The Lost Symbol</i>,<i>&#160;Angels &amp; Demons</i>,&#160;<i>Deception Point,</i>&#160;and&#160;<i>Digital Fortress</i>.<br><b><br>Dan Brown&#160;</b>es el autor de m&uacute;ltiples bestsellers internacionales<i>&#160;</i>incluyendo&#160;<i>El c&oacute;digo Da Vinci</i>,&#160;<i>Inferno</i>,<i>&#160;El s&iacute;mbolo perdido</i>,&#160;<i>&Aacute;ngeles y demonios, La fortaleza digital&#160;</i>y<i>&#160;La conspiraci&oacute;n</i>. Sus novelas han sido traducidas a 56 idiomas alrededor del mundo, con mas de 200 millones de copias actualmente impresas. En 2005, fue nombrado una de las 100 personas mas influenciales del mundo por la revista&#160;<i>Time.</i>&#160;Vive en Nueva Inglaterra con su esposa.",
#         "works": {
#             "works": [
#                 "19306",
#                 "19308",
#                 "19309",
#                 "19310",
#                 "19311",
#                 "19312",
#                 "19314",
#                 "68980",
#                 "203096",
#                 "204509",
#                 "227777",
#                 "228145",
#                 "248567",
#                 "249100",
#                 "300240",
#                 "549111",
#                 "549656",
#                 "554852",
#                 "555126",
#                 "612065"
#             ]
#         }
#     }
# }

# %% [markdown]
# #### Get the Authorlastfirst value and Spotlight value from json_text

# %% [markdown]
# <span style="color:blue">
#     <ul>
#         <li>Get the <strong>authorlastfirst</strong> value </li>
#         <li>Save the <strong>authorlastfirst</strong> value in a variable named <strong>author_last_first</strong>
#         <li>Print the <strong>author_last_first</strong> -- format the output as follows "AUTHOR (LAST,FIRST): xxxxxxxxx"</li>
#         <li>Get the <strong>spotlight</strong> value </li>
#         <li>Save the <strong>spotlight</strong> value in a variable named <strong>spot_light</strong>
#         <li>Print the <strong>spot_light</strong> -- format the output as follows "SPOTLIGHT: xxxxxxxxx"</li>
#     </ul>
# </span>

# %%
# INSERT PRINT OF JSON 'authorlastfirst' and 'spotlight' VALUES
author_last_first = text_json['author']['authorlastfirst']
print('AUTHOR (LAST,FIRST): ',author_last_first)
spot_light = text_json['author']['spotlight']
print('SPOTLIGHT: ',spot_light)
# Out:
# AUTHOR (LAST,FIRST):  BROWN, DAN
# SPOTLIGHT:  <b> <b>Dan Brown</b>&#160;</b>is the author of numerous #1 international bestsellers, including&#160;<i>The Da Vinci Code,&#160;<i>Origin,</i> Inferno</i>,&#160;<i>The Lost Symbol</i>,<i>&#160;Angels &amp; Demons</i>,&#160;<i>Deception Point,</i>&#160;and&#160;<i>Digital Fortress</i>.<br><b><br>Dan Brown&#160;</b>es el autor de m&uacute;ltiples bestsellers internacionales<i>&#160;</i>incluyendo&#160;<i>El c&oacute;digo Da Vinci</i>,&#160;<i>Inferno</i>,<i>&#160;El s&iacute;mbolo perdido</i>,&#160;<i>&Aacute;ngeles y demonios, La fortaleza digital&#160;</i>y<i>&#160;La conspiraci&oacute;n</i>. Sus novelas han sido traducidas a 56 idiomas alrededor del mundo, con mas de 200 millones de copias actualmente impresas. En 2005, fue nombrado una de las 100 personas mas influenciales del mundo por la revista&#160;<i>Time.</i>&#160;Vive en Nueva Inglaterra con su esposa.

# %% [markdown]
# ### Search for Works -- Use the GET /resources/works API  (18 Points)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     The <strong>Method Details</strong> for the <strong>GET /resources/works</strong> API can be found at the following link. <strong>HINT:</strong> To see an example of the URL syntax for this request, take a look at the <strong>USAGE</strong> section and click on <strong>expand source</strong> under <strong>bash</strong>.
#
#     http://www.penguinrandomhouse.biz/webservices/rest/#works
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <strong>ATTENTION:</strong> Contrary to the 'bash' example, using ?keyword='XXXXX' returns a 404 - Not Found ERROR<br>
#     Use <strong>search</strong> instead of <strong>keyword</strong> and the GET request will work correctly.
# </div>

# %% [markdown]
# #### Search for work:  'The Da Vinci Code'

# %% [markdown]
# <span style="color:blue">
#     <ul>
#         <li>Use the <strong>Penguin Random House API</strong> to do a <strong>GET works</strong> request </li>
#         <li>Include <strong>search</strong> for work <strong>Da Vinci Code</strong> </li>
#         <li>Include <strong>headers</strong> value of <strong>'Accept': 'application/json'</strong> </li>
#         <li>Print the Response <strong>text</strong></li>
#     </ul>
# </span>

# %%
# INSERT GET FOR WORK 'THE DA VINCI CODE'
payload = {'search':'Da Vinci Code'}
url = 'https://reststop.randomhouse.com/resources/works'
headers = {'Accept':'application/json'}
r = requests.get(url, headers = headers, verify = False, params=payload)
print(r.text)
# Out:
# {"@uri":"https://reststop.randomhouse.com/resources/works?search=Da+Vinci+Code","work":[{"@uri":"https://reststop.randomhouse.com/resources/works/19309","authorweb":"BROWN, DAN","titles":{"isbn":[{"@formatcode":"DN","$":"9780739340653"},{"@formatcode":"MM","$":"9780307474278"},{"@formatcode":"EL","$":"9780385504218"},{"@formatcode":"DN","$":"9781415934777"},{"@formatcode":"TR","$":"9780739326749"},{"@formatcode":"TR","$":"9780307277671"},{"@formatcode":"MM","$":"9780525565857"},{"@formatcode":"CD","$":"9780307879257"},{"@formatcode":"DN","$":"9780739353127"},{"@formatcode":"HC","$":"9780385504201"}]},"onsaledate":"2003-03-18T00:00:00-05:00","rgabout":"The following questions are intended to enhance your discussion, spotlight memorable passages, and make your reading experience of The Da Vinci Code even livelier.","rgauthbio":"<b>DAN BROWN</b> is the bestselling author of <i>Digital Fortress, Angels &amp; Demons</i>, and <i>Deception Point</i>. He lives in New England.","rgcopy":"While in Paris on business, Harvard symbologist Robert Langdon receives an urgent late-night phone call: the elderly curator of the Louvre has been murdered inside the museum. Near the body, police have found a baffling cipher. Solving the enigmatic riddle, Langdon is stunned to discover it leads to a trail of clues hidden in the works of Da Vinci&#8230;clues visible for all to see&#8230;and yet ingeniously disguised by the painter.<br><br>Langdon joins forces with a gifted French cryptologist, Sophie Neveu, and learns the late curator was involved in the Priory of Sion&#8212;an actual secret society whose members included Sir Isaac Newton, Botticelli, Victor Hugo, and Da Vinci, among others. The Louvre curator has sacrificed his life to protect the Priory's most sacred trust: the location of a vastly important religious relic, hidden for centuries. <br><br>In a breathless race through Paris, London, and beyond, Langdon and Neveu match wits with a faceless powerbroker who appears to work for Opus Dei&#8212;a clandestine, Vatican-sanctioned Catholic sect believed to have long plotted to seize the Priory's secret. Unless Langdon and Neveu can decipher the labyrinthine puzzle in time, the Priory's secret&#8212;and a stunning historical truth&#8212;will be lost forever. <br><br>In an exhilarating blend of relentless adventure, scholarly intrigue, and cutting wit, symbologist Robert Langdon (first introduced in Dan Brown's bestselling Angels &amp; Demons) is the most original character to appear in years. THE DA VINCI CODE heralds the arrival of a new breed of lightening-paced, intelligent thriller&#8230;surprising at every twist, absorbing at every turn, and in the end, utterly unpredictable&#8230;right up to its astonishing conclusion.","rgdiscussion":"<p>1. As a symbologist, Robert Langdon has a wealth of academic knowledge that helps him view the world in a unique way. Now that you&#8217;ve read <i>The Da Vinci Code</i>, are there any aspects of life/history/faith that <i>you</i> are seeing in a different light?</p><p>2. Langdon and Teabing disagree as to whether the Sangreal documents should be released to the world. If you were the Grand Master of the Priory of Sion, would you release the documents? If so, what do you think their effect would be?</p><p>3. What observations does this novel make about our past? How do these ideas relate to our future?</p><p>4. Other than his fear of being framed for murder, what motivates Langdon to follow this perilous quest? Do his motivations change?</p><p>5. The novel&#8217;s &#8220;quest&#8221; involves numerous puzzles and codes. Did you enjoy trying to solve these puzzles along with the characters? Did you solve any of the puzzles before the characters did?</p><p>6. If you could spend a day in any of the places described in this novel, where would it be, and why? The Louvre? Westminster Abbey? Rosslyn Chapel? The Temple Church? Somewhere else?</p><p>7. Historian Leigh Teabing claims the founding fathers of Christ ...

# %% [markdown]
# #### Use "Pretty JSON" formatting to prit the JSON for easier reading

# %% [markdown]
# <span style="color:blue">
#     <ul>
#         <li>Use <strong>json.loads</strong> to convert the text string into a Python dict</li>
#         <li>Save the value in variable <strong>text_json</strong></li>
#         <li>Print <strong>text_json</strong> using <strong>json.dumps</strong> with <strong>indent=4, sort_keys=True</strong> to make it easier to read (see Lab8)</li>
#     </ul>
# </span>

# %%
# INSERT JSON.LOADS and JSON.DUMPS CODE (Ref: Pretty JSON print)
text_json = json.loads(r.text)
print(json.dumps(text_json, indent=4, sort_keys=True))
# Out:
# {
#     "@uri": "https://reststop.randomhouse.com/resources/works?search=Da+Vinci+Code",
#     "work": [
#         {
#             "@uri": "https://reststop.randomhouse.com/resources/works/19309",
#             "authorweb": "BROWN, DAN",
#             "onsaledate": "2003-03-18T00:00:00-05:00",
#             "rgabout": "The following questions are intended to enhance your discussion, spotlight memorable passages, and make your reading experience of The Da Vinci Code even livelier.",
#             "rgauthbio": "<b>DAN BROWN</b> is the bestselling author of <i>Digital Fortress, Angels &amp; Demons</i>, and <i>Deception Point</i>. He lives in New England.",
#             "rgcopy": "While in Paris on business, Harvard symbologist Robert Langdon receives an urgent late-night phone call: the elderly curator of the Louvre has been murdered inside the museum. Near the body, police have found a baffling cipher. Solving the enigmatic riddle, Langdon is stunned to discover it leads to a trail of clues hidden in the works of Da Vinci&#8230;clues visible for all to see&#8230;and yet ingeniously disguised by the painter.<br><br>Langdon joins forces with a gifted French cryptologist, Sophie Neveu, and learns the late curator was involved in the Priory of Sion&#8212;an actual secret society whose members included Sir Isaac Newton, Botticelli, Victor Hugo, and Da Vinci, among others. The Louvre curator has sacrificed his life to protect the Priory's most sacred trust: the location of a vastly important religious relic, hidden for centuries. <br><br>In a breathless race through Paris, London, and beyond, Langdon and Neveu match wits with a faceless powerbroker who appears to work for Opus Dei&#8212;a clandestine, Vatican-sanctioned Catholic sect believed to have long plotted to seize the Priory's secret. Unless Langdon and Neveu can decipher the labyrinthine puzzle in time, the Priory's secret&#8212;and a stunning historical truth&#8212;will be lost forever. <br><br>In an exhilarating blend of relentless adventure, scholarly intrigue, and cutting wit, symbologist Robert Langdon (first introduced in Dan Brown's bestselling Angels &amp; Demons) is the most original character to appear in years. THE DA VINCI CODE heralds the arrival of a new breed of lightening-paced, intelligent thriller&#8230;surprising at every twist, absorbing at every turn, and in the end, utterly unpredictable&#8230;right up to its astonishing conclusion.",
#             "rgdiscussion": "<p>1. As a symbologist, Robert Langdon has a wealth of academic knowledge that helps him view the world in a unique way. Now that you&#8217;ve read <i>The Da Vinci Code</i>, are there any aspects of life/history/faith that <i>you</i> are seeing in a different light?</p><p>2. Langdon and Teabing disagree as to whether the Sangreal documents should be released to the world. If you were the Grand Master of the Priory of Sion, would you release the documents? If so, what do you think their effect would be?</p><p>3. What observations does this novel make about our past? How do these ideas relate to our future?</p><p>4. Other than his fear of being framed for murder, what motivates Langdon to follow this perilous quest? Do his motivations change?</p><p>5. The novel&#8217;s &#8220;quest&#8221; involves numerous puzzles and codes. Did you enjoy trying to solve these puzzles along with the characters? Did you solve any of the puzzles before the characters did?</p><p>6. If you could spend a day in any of the places described in this novel, where would it be, and why? The Louvre? Westminster Abbey? Rosslyn Chapel? The Temple Church? Somewhere else?</p><p>7. Historian Leigh Teabing claims the founding fathers of Christianity hijacked the good name of Jesus for political reasons. Do you agree? Does the historical evidence support Teabing&#8217;s claim?</p><p>8. Has this book changed your ideas about faith, religion, or history in any way?</p><p>9. Would you rather live in a world without religion&#8230;or a world without science?</p><p>10. Sauni&#232;re placed a lot of confidence in Langdon. Was this confidence well-placed? What other options might Sauni&#232;re have had? Did Sauni&#232;re make the right decision separating Sophie from the rest of her family?</p><p>11. Do you imagine Langdon should forgive Teabing for his misguided actions? On the other hand, do you think Teabing should forgive Langdon for refusing to release the Sangreal documents?</p><p>12. Does the world have a right to know <i>all</i> aspects of its history, or can an argument be made for keeping certain information secret?</p><p>13. What is interesting about the way this story is told? How are the episodes of the novel arranged and linked? In your discussion, you might want to identify where the turning points in the action are where those moments are after which everything is different. Did you anticipate them?</p><p>14. What is the novel's theme? What central message or idea links all the other components of the novel together?</p><p>15. For most people, the word &#8220;God&#8221; feels holy, while the word &#8220;Goddess&#8221; feels mythical. What are your thoughts on this? Do you imagine those perceptions will ever change?</p><p>16. Will you look at the artwork of Da Vinci any differently now that you know more about his &#8220;secret life?&#8221;</p>",
#             "series": "Robert Langdon",
#             "titleAuth": "The Da Vinci Code : Dan Brown",
#             "titleSubtitleAuth": "The Da Vinci Code : A Novel : Dan Brown",
#             "titles": {
#                 "isbn": [
#                     {
#                         "$": "9780739340653",
#                         "@formatcode": "DN"
#                     },
#                     {
#                         "$": "9780307474278",
#                         "@formatcode": "MM"
#                     },
#                     {
#                         "$": "9780385504218",
#                         "@formatcode": "EL"
#                     },
#                     {
#                         "$": "9781415934777",
#                         "@formatcode": "DN"
#                     },
#                     {
#                         "$": "9780739326749",
#                         "@formatcode": "TR"
#                     },
#                     {
#                         "$": "9780307277671",
#                         "@formatcode": "TR"
#                     },
#                     {
#                         "$": "9780525565857",
#                         "@formatcode": "MM"
#                     },
#                     {
#                         "$": "9780307879257",
#                         "@formatcode": "CD"
#                     },
#                     {
#                         "$": "9780739353127",
#                         "@formatcode": "DN"
#                     },
#                     {
#                         "$": "9780385504201",
#                         "@formatcode": "HC"
#                     }
#                 ]
#             },
#             "titleshort": "DA VINCI CODE (CD)(RI)",
#             "titleweb": "The Da Vinci Code",
#             "workid": "19309"
#         },
#         {
#             "@uri": "https://reststop.randomhouse.com/resources/works/19311",
#             "authorweb": "BROWN, DAN",
#             "onsaledate": "2004-11-02T00:00:00-05:00",
#             "rgabout": "The following questions are intended to enhance your discussion, spotlight memorable passages, and make your reading experience of The Da Vinci Code even livelier.",
#             "rgauthbio": "<b>DAN BROWN</b> is the bestselling author of <i>Digital Fortress, Angels &amp; Demons</i>, and <i>Deception Point</i>. He lives in New England.",
#             "rgcopy": "While in Paris on business, Harvard symbologist Robert Langdon receives an urgent late-night phone call: the elderly curator of the Louvre has been murdered inside the museum. Near the body, police have found a baffling cipher. Solving the enigmatic riddle, Langdon is stunned to discover it leads to a trail of clues hidden in the works of Da Vinci&#8230;clues visible for all to see&#8230;and yet ingeniously disguised by the painter.<br><br>Langdon joins forces with a gifted French cryptologist, Sophie Neveu, and learns the late curator was involved in the Priory of Sion&#8212;an actual secret society whose members included Sir Isaac Newton, Botticelli, Victor Hugo, and Da Vinci, among others. The Louvre curator has sacrificed his life to protect the Priory's most sacred trust: the location of a vastly important religious relic, hidden for centuries. <br><br>In a breathless race through Paris, London, and beyond, Langdon and Neveu match wits with a faceless powerbroker who appears to work for Opus Dei&#8212;a clandestine, Vatican-sanctioned Catholic sect believed to have long plotted to seize the Priory's secret. Unless Langdon and Neveu can decipher the labyrinthine puzzle in time, the Priory's secret&#8212;and a stunning historical truth&#8212;will be lost forever. <br><br>In an exhilarating blend of relentless adventure, scholarly intrigue, and cutting wit, symbologist Robert Langdon (first introduced in Dan Brown's bestselling Angels &amp; Demons) is the most original character to appear in years. THE DA VINCI CODE heralds the arrival of a new breed of lightening-paced, intelligent thriller&#8230;surprising at every twist, absorbing at every turn, and in the end, utterly unpredictable&#8230;right up to its astonishing conclusion.",
#             "rgdiscussion": "<p>1. As a symbologist, Robert Langdon has a wealth of academic knowledge that helps him view the world in a unique way. Now that you&#8217;ve read <i>The Da Vinci Code</i>, are there any aspects of life/history/faith that <i>you</i> are seeing in a different light?</p><p>2. Langdon and Teabing disagree as to whether the Sangreal documents should be released to the world. If you were the Grand Master of the Priory of Sion, would you release the documents? If so, what do you think their effect would be?</p><p>3. What observations does this novel make about our past? How do these ideas relate to our future?</p><p>4. Other than his fear of being framed for murder, what motivates Langdon to follow this perilous quest? Do his motivations change?</p><p>5. The novel&#8217;s &#8220;quest&#8221; involves numerous puzzles and codes. Did you enjoy trying to solve these puzzles along with the characters? Did you solve any of the puzzles before the characters did?</p><p>6. If you could spend a day in any of the places described in this novel, where would it be, and why? The Louvre? Westminster Abbey? Rosslyn Chapel? The Temple Church? Somewhere else?</p><p>7. Historian Leigh Teabing claims the founding fathers of Christianity hijacked the good name of Jesus for political reasons. Do you agree? Does the historical evidence support Teabing&#8217;s claim?</p><p>8. Has this book changed your ideas about faith, religion, or history in any way?</p><p>9. Would you rather live in a world without religion&#8230;or a world without science?</p><p>10. Sauni&#232;re placed a lot of confidence in Langdon. Was this confidence well-placed? What other options might Sauni&#232;re have had? Did Sauni&#232;re make the right decision separating Sophie from the rest of her family?</p><p>11. Do you imagine Langdon should forgive Teabing for his misguided actions? On the other hand, do you think Teabing should forgive Langdon for refusing to release the Sangreal documents?</p><p>12. Does the world have a right to know <i>all</i> aspects of its history, or can an argument be made for keeping certain information secret?</p><p>13. What is interesting about the way this story is told? How are the episodes of the novel arranged and linked? In your discussion, you might want to identify where the turning points in the action are where those moments are after which everything is different. Did you anticipate them?</p><p>14. What is the novel's theme? What central message or idea links all the other components of the novel together?</p><p>15. For most people, the word &#8220;God&#8221; feels holy, while the word &#8220;Goddess&#8221; feels mythical. What are your thoughts on this? Do you imagine those perceptions will ever change?</p><p>16. Will you look at the artwork of Da Vinci any differently now that you know more about his &#8220;secret life?&#8221;</p>",
#             "titleAuth": "The Da Vinci Code: Special Illustrated Edition : Dan Brown",
#             "titleSubtitleAuth": "The Da Vinci Code: Special Illustrated Edition :  : Dan Brown",
#             "titles": {
#                 "isbn": [
#                     {
#                         "$": "9780767926034",
#                         "@formatcode": "TR"
#                     },
#                     {
#                         "$": "9780385513753",
#                         "@formatcode": "HC"
#                     }
#                 ]
#             },
#             "titleshort": "DA VINCI CODE: SPECIAL ILLUSTR",
#             "titleweb": "The Da Vinci Code: Special Illustrated Edition",
#             "workid": "19311"
#         },
#         {
#             "@uri": "https://reststop.randomhouse.com/resources/works/549656",
#             "authorweb": "BROWN, DAN",
#             "onsaledate": "2016-09-13T00:00:00-04:00",
#             "titleAuth": "The Da Vinci Code (The Young Adult Adaptation) : Dan Brown",
#             "titleSubtitleAuth": "The Da Vinci Code (The Young Adult Adaptation) :  : Dan Brown",
#             "titles": {
#                 "isbn": [
#                     {
#                         "$": "9781524715847",
#                         "@formatcode": "EL"
#                     },
#                     {
#                         "$": "9781524734893",
#                         "@formatcode": "DN"
#                     },
#                     {
#                         "$": "9781524734879",
#                         "@formatcode": "DN"
#                     },
#                     {
#                         "$": "9781524715823",
#                         "@formatcode": "HC"
#                     }
#                 ]
#             },
#             "titleshort": "DA VINCI CODE (YA ED)(EBK)",
#             "titleweb": "The Da Vinci Code (The Young Adult Adaptation)",
#             "workid": "549656"
#         }
#     ]
# }

# %% [markdown]
# #### Get the workid value from json_text (Get the 1st one you see -- "workid": "19309")

# %% [markdown]
# <span style="color:blue">
#     <ul>
#         <li>Get the <strong>workid</strong> value </li>
#         <li>Save the <strong>workid</strong> in a variable named <strong>work_id</strong> </li>
#         <li>Print the <strong>work_id</strong> -- format the output as follows "WORK ID: xxxxx"</li>
#     </ul>
# </span>

# %%
# INSERT GET & PRINT OF JSON 'workid' VALUE -- "workid": "19309"
work_id = text_json['work'][0]['workid']
print('WORK ID: ',work_id)
# Out:
# WORK ID:  19309

# %% [markdown]
# ### Get details for a Specific Work -- Use the GET /resources/works/WORKID API  (18 Points)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     The <strong>Method Details</strong> for the <strong>GET /resources/works/WORKID</strong> API can be found at the following link. <strong>HINT:</strong> To see an example of the URL syntax for this request, take a look at the <strong>USAGE</strong> section and click on <strong>expand source</strong> under <strong>bash</strong>.
#
#     http://www.penguinrandomhouse.biz/webservices/rest/#work
# </div>

# %% [markdown]
# <span style="color:blue">
#     <ul>
#         <li>Use the <strong>Penguin Random House WORKID API</strong> to do a <strong>GET</strong> request using the <strong>work_id</strong> value/variable found in the previous step.</li>
#         <li>Include <strong>headers</strong> value of <strong>'Accept': 'application/json'</strong> </li>
#         <li>Print the Response <strong>text</strong></li>
#     </ul>
# </span>

# %%
# INSERT GET WORKID & PRINT RESPONSE TEXT
url = 'https://reststop.randomhouse.com/resources/works/'
headers = {'Accept':'application/json'}
r = requests.get(url+work_id, headers = headers, verify = False)
print(r.text)
# Out:
# {"@uri":"https://reststop.randomhouse.com/resources/works/19309","authorweb":"BROWN, DAN","titles":{"isbn":[{"@formatcode":"DN","$":"9780739340653"},{"@formatcode":"MM","$":"9780307474278"},{"@formatcode":"EL","$":"9780385504218"},{"@formatcode":"DN","$":"9781415934777"},{"@formatcode":"TR","$":"9780739326749"},{"@formatcode":"TR","$":"9780307277671"},{"@formatcode":"MM","$":"9780525565857"},{"@formatcode":"CD","$":"9780307879257"},{"@formatcode":"DN","$":"9780739353127"},{"@formatcode":"HC","$":"9780385504201"}]},"onsaledate":"2003-03-18T00:00:00-05:00","rgabout":"The following questions are intended to enhance your discussion, spotlight memorable passages, and make your reading experience of The Da Vinci Code even livelier.","rgauthbio":"<b>DAN BROWN</b> is the bestselling author of <i>Digital Fortress, Angels &amp; Demons</i>, and <i>Deception Point</i>. He lives in New England.","rgcopy":"While in Paris on business, Harvard symbologist Robert Langdon receives an urgent late-night phone call: the elderly curator of the Louvre has been murdered inside the museum. Near the body, police have found a baffling cipher. Solving the enigmatic riddle, Langdon is stunned to discover it leads to a trail of clues hidden in the works of Da Vinci&#8230;clues visible for all to see&#8230;and yet ingeniously disguised by the painter.<br><br>Langdon joins forces with a gifted French cryptologist, Sophie Neveu, and learns the late curator was involved in the Priory of Sion&#8212;an actual secret society whose members included Sir Isaac Newton, Botticelli, Victor Hugo, and Da Vinci, among others. The Louvre curator has sacrificed his life to protect the Priory's most sacred trust: the location of a vastly important religious relic, hidden for centuries. <br><br>In a breathless race through Paris, London, and beyond, Langdon and Neveu match wits with a faceless powerbroker who appears to work for Opus Dei&#8212;a clandestine, Vatican-sanctioned Catholic sect believed to have long plotted to seize the Priory's secret. Unless Langdon and Neveu can decipher the labyrinthine puzzle in time, the Priory's secret&#8212;and a stunning historical truth&#8212;will be lost forever. <br><br>In an exhilarating blend of relentless adventure, scholarly intrigue, and cutting wit, symbologist Robert Langdon (first introduced in Dan Brown's bestselling Angels &amp; Demons) is the most original character to appear in years. THE DA VINCI CODE heralds the arrival of a new breed of lightening-paced, intelligent thriller&#8230;surprising at every twist, absorbing at every turn, and in the end, utterly unpredictable&#8230;right up to its astonishing conclusion.","rgdiscussion":"<p>1. As a symbologist, Robert Langdon has a wealth of academic knowledge that helps him view the world in a unique way. Now that you&#8217;ve read <i>The Da Vinci Code</i>, are there any aspects of life/history/faith that <i>you</i> are seeing in a different light?</p><p>2. Langdon and Teabing disagree as to whether the Sangreal documents should be released to the world. If you were the Grand Master of the Priory of Sion, would you release the documents? If so, what do you think their effect would be?</p><p>3. What observations does this novel make about our past? How do these ideas relate to our future?</p><p>4. Other than his fear of being framed for murder, what motivates Langdon to follow this perilous quest? Do his motivations change?</p><p>5. The novel&#8217;s &#8220;quest&#8221; involves numerous puzzles and codes. Did you enjoy trying to solve these puzzles along with the characters? Did you solve any of the puzzles before the characters did?</p><p>6. If you could spend a day in any of the places described in this novel, where would it be, and why? The Louvre? Westminster Abbey? Rosslyn Chapel? The Temple Church? Somewhere else?</p><p>7. Historian Leigh Teabing claims the founding fathers of Christianity hijacked the good name of Jesus for political reasons. Do you agree? Does the his ...

# %% [markdown]
# #### Use "Pretty JSON" formatting to print the JSON for easier reading

# %% [markdown]
# <span style="color:blue">
#     <ul>
#         <li>Use <strong>json.loads</strong> to convert the text string into a Python dict</li>
#         <li>Save the value in variable <strong>text_json</strong></li>
#         <li>Print <strong>text_json</strong> using <strong>json.dumps</strong> with <strong>indent=4, sort_keys=True</strong> to make it easier to read (see Lab8)</li>
#     </ul>
# </span>

# %%
# INSERT JSON.LOADS and JSON.DUMPS CODE (Ref: Pretty JSON print)
text_json = json.loads(r.text)
print(json.dumps(text_json, indent=4, sort_keys=True))
# Out:
# {
#     "@uri": "https://reststop.randomhouse.com/resources/works/19309",
#     "authorweb": "BROWN, DAN",
#     "onsaledate": "2003-03-18T00:00:00-05:00",
#     "rgabout": "The following questions are intended to enhance your discussion, spotlight memorable passages, and make your reading experience of The Da Vinci Code even livelier.",
#     "rgauthbio": "<b>DAN BROWN</b> is the bestselling author of <i>Digital Fortress, Angels &amp; Demons</i>, and <i>Deception Point</i>. He lives in New England.",
#     "rgcopy": "While in Paris on business, Harvard symbologist Robert Langdon receives an urgent late-night phone call: the elderly curator of the Louvre has been murdered inside the museum. Near the body, police have found a baffling cipher. Solving the enigmatic riddle, Langdon is stunned to discover it leads to a trail of clues hidden in the works of Da Vinci&#8230;clues visible for all to see&#8230;and yet ingeniously disguised by the painter.<br><br>Langdon joins forces with a gifted French cryptologist, Sophie Neveu, and learns the late curator was involved in the Priory of Sion&#8212;an actual secret society whose members included Sir Isaac Newton, Botticelli, Victor Hugo, and Da Vinci, among others. The Louvre curator has sacrificed his life to protect the Priory's most sacred trust: the location of a vastly important religious relic, hidden for centuries. <br><br>In a breathless race through Paris, London, and beyond, Langdon and Neveu match wits with a faceless powerbroker who appears to work for Opus Dei&#8212;a clandestine, Vatican-sanctioned Catholic sect believed to have long plotted to seize the Priory's secret. Unless Langdon and Neveu can decipher the labyrinthine puzzle in time, the Priory's secret&#8212;and a stunning historical truth&#8212;will be lost forever. <br><br>In an exhilarating blend of relentless adventure, scholarly intrigue, and cutting wit, symbologist Robert Langdon (first introduced in Dan Brown's bestselling Angels &amp; Demons) is the most original character to appear in years. THE DA VINCI CODE heralds the arrival of a new breed of lightening-paced, intelligent thriller&#8230;surprising at every twist, absorbing at every turn, and in the end, utterly unpredictable&#8230;right up to its astonishing conclusion.",
#     "rgdiscussion": "<p>1. As a symbologist, Robert Langdon has a wealth of academic knowledge that helps him view the world in a unique way. Now that you&#8217;ve read <i>The Da Vinci Code</i>, are there any aspects of life/history/faith that <i>you</i> are seeing in a different light?</p><p>2. Langdon and Teabing disagree as to whether the Sangreal documents should be released to the world. If you were the Grand Master of the Priory of Sion, would you release the documents? If so, what do you think their effect would be?</p><p>3. What observations does this novel make about our past? How do these ideas relate to our future?</p><p>4. Other than his fear of being framed for murder, what motivates Langdon to follow this perilous quest? Do his motivations change?</p><p>5. The novel&#8217;s &#8220;quest&#8221; involves numerous puzzles and codes. Did you enjoy trying to solve these puzzles along with the characters? Did you solve any of the puzzles before the characters did?</p><p>6. If you could spend a day in any of the places described in this novel, where would it be, and why? The Louvre? Westminster Abbey? Rosslyn Chapel? The Temple Church? Somewhere else?</p><p>7. Historian Leigh Teabing claims the founding fathers of Christianity hijacked the good name of Jesus for political reasons. Do you agree? Does the historical evidence support Teabing&#8217;s claim?</p><p>8. Has this book changed your ideas about faith, religion, or history in any way?</p><p>9. Would you rather live in a world without religion&#8230;or a world without science?</p><p>10. Sauni&#232;re placed a lot of confidence in Langdon. Was this confidence well-placed? What other options might Sauni&#232;re have had? Did Sauni&#232;re make the right decision separating Sophie from the rest of her family?</p><p>11. Do you imagine Langdon should forgive Teabing for his misguided actions? On the other hand, do you think Teabing should forgive Langdon for refusing to release the Sangreal documents?</p><p>12. Does the world have a right to know <i>all</i> aspects of its history, or can an argument be made for keeping certain information secret?</p><p>13. What is interesting about the way this story is told? How are the episodes of the novel arranged and linked? In your discussion, you might want to identify where the turning points in the action are where those moments are after which everything is different. Did you anticipate them?</p><p>14. What is the novel's theme? What central message or idea links all the other components of the novel together?</p><p>15. For most people, the word &#8220;God&#8221; feels holy, while the word &#8220;Goddess&#8221; feels mythical. What are your thoughts on this? Do you imagine those perceptions will ever change?</p><p>16. Will you look at the artwork of Da Vinci any differently now that you know more about his &#8220;secret life?&#8221;</p>",
#     "series": "Robert Langdon",
#     "titleAuth": "The Da Vinci Code : Dan Brown",
#     "titleSubtitleAuth": "The Da Vinci Code : A Novel : Dan Brown",
#     "titles": {
#         "isbn": [
#             {
#                 "$": "9780739340653",
#                 "@formatcode": "DN"
#             },
#             {
#                 "$": "9780307474278",
#                 "@formatcode": "MM"
#             },
#             {
#                 "$": "9780385504218",
#                 "@formatcode": "EL"
#             },
#             {
#                 "$": "9781415934777",
#                 "@formatcode": "DN"
#             },
#             {
#                 "$": "9780739326749",
#                 "@formatcode": "TR"
#             },
#             {
#                 "$": "9780307277671",
#                 "@formatcode": "TR"
#             },
#             {
#                 "$": "9780525565857",
#                 "@formatcode": "MM"
#             },
#             {
#                 "$": "9780307879257",
#                 "@formatcode": "CD"
#             },
#             {
#                 "$": "9780739353127",
#                 "@formatcode": "DN"
#             },
#             {
#                 "$": "9780385504201",
#                 "@formatcode": "HC"
#             }
#         ]
#     },
#     "titleshort": "DA VINCI CODE (CD)(RI)",
#     "titleweb": "The Da Vinci Code",
#     "workid": "19309"
# }

# %% [markdown]
# #### Get & print multiple values from json_text

# %% [markdown]
# <span style="color:blue">
#     <ul>
#         <li>Get &amp; print the <strong>authorweb</strong> -- format the output as follows "AUTHORWEB: xxxxx" </li>
#         <li>Get &amp; print the <strong>onsaledate</strong> -- format the output as follows "ONSALEDATE: xxxxx" </li>
#         <li>Get &amp; print the <strong>rgauthbio</strong> -- format the output as follows "RGAUTHBIO: xxxxx" </li>
#     </ul>
# </span>

# %%
# INSERT PRINT OF JSON 'authorweb', 'onsaledate' and 'rgauthbio' VALUES
authorweb = text_json['authorweb']
onsaledate = text_json['onsaledate']
rgauthbio = text_json['rgauthbio']
print('AUTHORWEB: ',authorweb)
print('ONSALEDATE: ',onsaledate)
print('RGAUTHBIO: ',rgauthbio)
# Out:
# AUTHORWEB:  BROWN, DAN
# ONSALEDATE:  2003-03-18T00:00:00-05:00
# RGAUTHBIO:  <b>DAN BROWN</b> is the bestselling author of <i>Digital Fortress, Angels &amp; Demons</i>, and <i>Deception Point</i>. He lives in New England.

# %% [markdown]
# ### Search for titles by Dan Brown -- Use the GET /resources/titles API (18 Points)

# %% [markdown]
# <div class="alert alert-block alert-info">
#     The <strong>Method Details</strong> for the <strong>GET /resources/titles</strong> API can be found at the following link. <strong>HINT:</strong> To see an example of the URL syntax for this request, take a look at the <strong>USAGE</strong> section and click on <strong>expand source</strong> under <strong>bash</strong>.
#
#     http://www.penguinrandomhouse.biz/webservices/rest/#titles
# </div>

# %% [markdown]
# <span style="color:blue">
#     Search by <strong>titles</strong> - But ONLY get the first <strong>4 (max=4)</strong> to limit the number of books returned. Use Dan Brown's <strong>author_id</strong> (saved earlier in the lab)
#     <ul>
#         <li>Use the <strong>Penguin Random House TITLES API</strong> to do a <strong>GET</strong> request </li>
#         <li>Include <strong>start</strong> and <strong>max</strong> values to limit the titles to <strong>4</strong></li>
#         <li>Include the <strong>author_id</strong> found in the previously (for Dan Brown) </li>
#         <li>Include <strong>headers</strong> value of <strong>'Accept': 'application/json'</strong> </li>
#         <li>Print the Response <strong>text</strong></li>
#     </ul>
# </span>

# %%
# INSERT GET TITLES WITH MAX 4 AND AUTHORID FOR DAN BROWN
payload = {'start':0, 'max':4,'expandLevel':1, 'authorid':author_id}
url = 'https://reststop.randomhouse.com/resources/titles'
headers = {'Accept':'application/json'}
r = requests.get(url, headers = headers, verify = False, params=payload)
print(r.url)
print(r.text)
# Out:
# https://reststop.randomhouse.com/resources/titles?start=0&max=4&expandLevel=1&authorid=3446
# {"@uri":"https://reststop.randomhouse.com/resources/titles?start=0&max=4&expandLevel=1&authorid=3446","title":[{"@uri":"https://reststop.randomhouse.com/resources/titles/9780307277671","acmartflap":"While in Paris, Harvard symbologist Robert Langdon is awakened by a phone call in  the dead of the night. The elderly curator of the Louvre has been murdered inside  the museum, his body covered in baffling symbols. As Langdon and gifted French cryptologist  Sophie Neveu sort through the bizarre riddles, they are stunned to discover a trail  of clues hidden in the works of Leonardo da Vinci&mdash;clues visible for all to see and  yet ingeniously disguised by the painter.<br> Even more startling, the late curator was  involved in the Priory of Sion&mdash;a secret society whose members included Sir Isaac  Newton, Victor Hugo, and Da Vinci&mdash;and he guarded a breathtaking historical secret.  Unless Langdon and Neveu can decipher the labyrinthine puzzle&mdash;while avoiding the  faceless adversary who shadows their every move&mdash;the explosive, ancient truth will  be lost forever.<br><br>\"Read the book and be enlightened.\" &mdash;<i>The Washington Post Book World<br></i><br> &ldquo;Blockbuster perfection. . . . A gleefully erudite suspense novel.&rdquo;&mdash;<i>The New York  Times</i>","author":"BROWN, DAN","authors":{"authorId":{"@contributortype":"A","$":"3446"}},"authorbio":"<b>DAN BROWN</b> is the bestselling author of <i>Digital Fortress, Angels &amp; Demons</i>, and <i>Deception Point</i>. He lives in New England.","authorweb":"Dan Brown","awards":null,"characters":null,"contributorfirst1":"Dan","contributorlast1":"Brown","division":"Knopf","excerpt":"1<br><br>Robert Langdon awoke slowly.<br><br>A telephone was ringing in the darkness--a tinny, unfamiliar ring. He fumbled for the bedside lamp and turned it on. Squinting at his surroundings he saw a plush Renaissance bedroom with Louis XVI furniture, hand-frescoed walls, and a colossal mahogany four-poster bed.<br><br><i>Where the hell am I?</i><br><br>The jacquard bathrobe hanging on his bedpost bore the monogram: <br><br>HOTEL RITZ PARIS.<br><br>Slowly, the fog began to lift.<br><br>Langdon picked up the receiver. &quot;Hello?&quot;<br><br>&quot;Monsieur Langdon?&quot; a man's voice said. &quot;I hope I have not awoken you?&quot;<br><br>Dazed, Langdon looked at the bedside clock. It was 12:32 A.M. He had been asleep only an hour, but he felt like the dead.<br><br>&quot;This is the concierge, monsieur. I apologize for this intrusion, but you have a visitor. He insists it is urgent.&quot;<br><br>Langdon still felt fuzzy. A <i>visitor</i>? His eyes focused now on a crumpled flyer on his bedside table.<br><br>THE AMERICAN UNIVERSITY OF PARIS<br>proudly presents<br>An evening with Robert Langdon<br>Professor of Religious Symbology, Harvard University<br><br>Langdon groaned. Tonight's lecture--a slide show about pagan symbolism hidden in the stones of Chartres Cathedral--had probably ruffled some conservative feathers in the audience. Most likely, some religious scholar had trailed him home to pick a fight.<br><br>&quot;I'm sorry,&quot; Langdon said, &quot;but I'm very tired and--&quot;<br><br><i>&quot;Mais monsieur</i>,&quot; the concierge pressed, lowering his voice to an urgent whisper. &quot;Your guest is an important man.&quot;<br><br>Langdon had little doubt. His books on religious paintings and cult symbology had made him a reluctant celebrity in the art world, and last year Langdon's visibility had increased a hundred-fold after his involvement in a widely publicized incident at the Vatican. Since then, the stream of self-important historians and art buffs arriving at his door had seemed never-ending.<br><br>&quot;If you would be so kind,&quot; Langdon said, doing his best to remain polite, &quot;could you take the man's name and number, and tell him I'll try to call him before I leave Paris on Tuesday? Thank you.&quot; He hung up before the concierge could protest.<br ...

# %% [markdown]
# #### Use "Pretty JSON" formatting to print the JSON for easier reading

# %% [markdown]
# <span style="color:blue">
#     <ul>
#         <li>Use <strong>json.loads</strong> to convert the text string into a Python dict</li>
#         <li>Save the value in variable <strong>text_json</strong></li>
#         <li>Print <strong>text_json</strong> using <strong>json.dumps</strong> with <strong>indent=4, sort_keys=True</strong> to make it easier to read (see Lab8)</li>
#     </ul>
# </span>

# %%
# INSERT JSON.LOADS and JSON.DUMPS CODE (Ref: Pretty JSON print)
text_json = json.loads(r.text)
print(json.dumps(text_json, indent=4, sort_keys=True))
# Out:
# {
#     "@uri": "https://reststop.randomhouse.com/resources/titles?start=0&max=4&expandLevel=1&authorid=3446",
#     "title": [
#         {
#             "@uri": "https://reststop.randomhouse.com/resources/titles/9780307277671",
#             "acmartflap": "While in Paris, Harvard symbologist Robert Langdon is awakened by a phone call in  the dead of the night. The elderly curator of the Louvre has been murdered inside  the museum, his body covered in baffling symbols. As Langdon and gifted French cryptologist  Sophie Neveu sort through the bizarre riddles, they are stunned to discover a trail  of clues hidden in the works of Leonardo da Vinci&mdash;clues visible for all to see and  yet ingeniously disguised by the painter.<br> Even more startling, the late curator was  involved in the Priory of Sion&mdash;a secret society whose members included Sir Isaac  Newton, Victor Hugo, and Da Vinci&mdash;and he guarded a breathtaking historical secret.  Unless Langdon and Neveu can decipher the labyrinthine puzzle&mdash;while avoiding the  faceless adversary who shadows their every move&mdash;the explosive, ancient truth will  be lost forever.<br><br>\"Read the book and be enlightened.\" &mdash;<i>The Washington Post Book World<br></i><br> &ldquo;Blockbuster perfection. . . . A gleefully erudite suspense novel.&rdquo;&mdash;<i>The New York  Times</i>",
#             "author": "BROWN, DAN",
#             "authorbio": "<b>DAN BROWN</b> is the bestselling author of <i>Digital Fortress, Angels &amp; Demons</i>, and <i>Deception Point</i>. He lives in New England.",
#             "authors": {
#                 "authorId": {
#                     "$": "3446",
#                     "@contributortype": "A"
#                 }
#             },
#             "authorweb": "Dan Brown",
#             "awards": null,
#             "characters": null,
#             "contributorfirst1": "Dan",
#             "contributorlast1": "Brown",
#             "division": "Knopf",
#             "excerpt": "1<br><br>Robert Langdon awoke slowly.<br><br>A telephone was ringing in the darkness--a tinny, unfamiliar ring. He fumbled for the bedside lamp and turned it on. Squinting at his surroundings he saw a plush Renaissance bedroom with Louis XVI furniture, hand-frescoed walls, and a colossal mahogany four-poster bed.<br><br><i>Where the hell am I?</i><br><br>The jacquard bathrobe hanging on his bedpost bore the monogram: <br><br>HOTEL RITZ PARIS.<br><br>Slowly, the fog began to lift.<br><br>Langdon picked up the receiver. &quot;Hello?&quot;<br><br>&quot;Monsieur Langdon?&quot; a man's voice said. &quot;I hope I have not awoken you?&quot;<br><br>Dazed, Langdon looked at the bedside clock. It was 12:32 A.M. He had been asleep only an hour, but he felt like the dead.<br><br>&quot;This is the concierge, monsieur. I apologize for this intrusion, but you have a visitor. He insists it is urgent.&quot;<br><br>Langdon still felt fuzzy. A <i>visitor</i>? His eyes focused now on a crumpled flyer on his bedside table.<br><br>THE AMERICAN UNIVERSITY OF PARIS<br>proudly presents<br>An evening with Robert Langdon<br>Professor of Religious Symbology, Harvard University<br><br>Langdon groaned. Tonight's lecture--a slide show about pagan symbolism hidden in the stones of Chartres Cathedral--had probably ruffled some conservative feathers in the audience. Most likely, some religious scholar had trailed him home to pick a fight.<br><br>&quot;I'm sorry,&quot; Langdon said, &quot;but I'm very tired and--&quot;<br><br><i>&quot;Mais monsieur</i>,&quot; the concierge pressed, lowering his voice to an urgent whisper. &quot;Your guest is an important man.&quot;<br><br>Langdon had little doubt. His books on religious paintings and cult symbology had made him a reluctant celebrity in the art world, and last year Langdon's visibility had increased a hundred-fold after his involvement in a widely publicized incident at the Vatican. Since then, the stream of self-important historians and art buffs arriving at his door had seemed never-ending.<br><br>&quot;If you would be so kind,&quot; Langdon said, doing his best to remain polite, &quot;could you take the man's name and number, and tell him I'll try to call him before I leave Paris on Tuesday? Thank you.&quot; He hung up before the concierge could protest.<br><br>Sitting up now, Langdon frowned at his bedside Guest Relations Handbook, whose cover boasted: SLEEP LIKE A BABY IN THE CITY OF LIGHTS. SLUMBER AT THE  PARIS RITZ.<br><br>He turned and gazed tiredly into the full-length mirror across the room. The man staring back at him was a stranger--tousled and weary.<br><br><i>You need a vacation, Robert.</i><br><br>The past year had taken a heavy toll on him, but he didn't appreciate seeing proof in the mirror. His usually sharp blue eyes looked hazy and drawn tonight. A dark stubble was shrouding his strong jaw and dimpled chin. Around his temples, the gray highlights were advancing, making their way deeper into his thicket of coarse black hair. Although his female colleagues insisted the gray only accentuated his bookish appeal, Langdon knew better.<br><br>If <i>Boston Magazine</i> could see me now.<br><br>Last month, much to Langdon's embarrassment, <i>Boston Magazine</i> had listed him as one of that city's top ten most intriguing people--a dubious honor that made him the brunt of endless ribbing by his Harvard colleagues. Tonight, three thousand miles from home, the accolade had resurfaced to haunt him at the lecture he had given.<br><br>&quot;Ladies and gentlemen . . .&quot; the hostess had announced to a full-house at The American University of Paris's <i>Pavillon Dauphine</i>, &quot;Our guest tonight needs no introduction. He is the author of numerous books: <i>The Symbology of Secret Sects, The Art of the Illuminati, The Lost Language of Ideograms</i>, and when I say he wrote the book on Religious Iconology, I mean that quite literally. Many of you use his textbooks in class.&quot; ...
#             "flapcopy": "<p><b>MORE THAN 80 MILLION COPIES SOLD<br><br><b><b>Nominated as one of America&rsquo;s best-loved novels by PBS&rsquo;s&#160;<i>The Great American Read</i></b></b></b><br><br>While in Paris, Harvard symbologist Robert Langdon is awakened  by a phone call in the dead of the night. The elderly curator of the Louvre has been  murdered inside the museum, his body covered in baffling symbols. As Langdon and  gifted French cryptologist Sophie Neveu sort through the bizarre riddles, they are  stunned to discover a trail of clues hidden in the works of Leonardo da Vinci&mdash;clues  visible for all to see and yet ingeniously disguised by the painter.</p><p>Even more startling,  the late curator was involved in the Priory of Sion&mdash;a secret society whose members  included Sir Isaac Newton, Victor Hugo, and Da Vinci&mdash;and he guarded a breathtaking  historical secret. Unless Langdon and Neveu can decipher the labyrinthine puzzle&mdash;while  avoiding the faceless adversary who shadows their every move&mdash;the explosive, ancient  truth will be lost forever.</p>",
#             "formatcode": "TR",
#             "formatname": "Trade Paperback",
#             "imprint": "Anchor",
#             "isbn": "9780307277671",
#             "isbn10": "0307277674",
#             "isbn10hyphenated": "0-307-27767-4",
#             "isbn13hyphenated": "978-0-307-27767-1",
#             "jacketquotes": "<p>\"Read the book and be enlightened.\" &mdash;<i>The Washington Post Book World</i></p><p>&ldquo;Blockbuster  perfection. . . . A gleefully erudite suspense novel.&rdquo;&mdash;<i>The New York Times</i></p><p>&ldquo;A pulse-quickening,  brain-teasing adventure.&rdquo; &mdash;<i>People</i></p><p>&ldquo;Thriller writing doesn&rsquo;t get any better than  this.&rdquo; &mdash;<i>The Denver Post</i></p>",
#             "keyword": "The Da Vinci Code :  : Dan Brown : Anchor : Fiction - Thrillers - Suspense : Fiction - Mystery & Detective - Historical : Fiction - Religious : 0307277674 : 0-307-27767-4 : 9780307277671 : 978-0-307-27767-1 : <p><b>MORE THAN 80 MILLION COPIES SOLD<br><br><b><b>Nominated as one of America&rsquo;s best-loved novels by PBS&rsquo;s&#160;<i>The Great American Read</i></b></b></b><br><br>While in Paris, Harvard symbologist Robert Langdon is awakened  by a phone call in the dead of the night. The elderly curator of the Louvre has been  murdered inside the museum, his body covered in baffling symbols. As Langdon and  gifted French cryptologist Sophie Neveu sort through the bizarre riddles, they are  stunned to discover a trail of clues hidden in the works of Leonardo da Vinci&mdash;clues  visible for all to see and yet ingeniously disguised by the painter.</p><p>Even more startling,  the late curator was involved in the Priory of Sion&mdash;a secret society whose members  included Sir Isaac Newton, Victor Hugo, and Da Vinci&mdash;and he guarded a breathtaking  historical secret. Unless Langdon and Neveu can decipher the labyrinthine puzzle&mdash;while  avoiding the faceless adversary who shadows their every move&mdash;the explosive, ancient  truth will be lost forever.</p>",
#             "links": {
#                 "link": {
#                     "ean": "9780307277671",
#                     "linkattr": "1000",
#                     "linkid": "9759",
#                     "linktext": "Official book site: www.TheDaVinciCo<wbr>de.com",
#                     "url": "http://www.randomhouse.com/doubleday/davinci/",
#                     "weblinkisbn": "30727767"
#                 }
#             },
#             "onsaledate": "03/28/2006",
#             "pages": "480",
#             "pricecanada": "22.95",
#             "priceusa": "16.95",
#             "relatedisbns": {
#                 "isbn": [
#                     {
#                         "$": "9780739340653",
#                         "@formatcode": "DN"
#                     },
#                     {
#                         "$": "9780307474278",
#                         "@formatcode": "MM"
#                     },
#                     {
#                         "$": "9780385504218",
#                         "@formatcode": "EL"
#                     },
#                     {
#                         "$": "9781415934777",
#                         "@formatcode": "DN"
#                     },
#                     {
#                         "$": "9780739326749",
#                         "@formatcode": "TR"
#                     },
#                     {
#                         "$": "9780307277671",
#                         "@formatcode": "TR"
#                     },
#                     {
#                         "$": "9780307879257",
#                         "@formatcode": "CD"
#                     },
#                     {
#                         "$": "9780385504201",
#                         "@formatcode": "HC"
#                     }
#                 ]
#             },
#             "rgabout": "The following questions are intended to enhance your discussion, spotlight memorable passages, and make your reading experience of <b>The Da Vinci Code</b> even livelier.",
#             "rgauthbio": "Dan Brown is the bestselling author of <b>Digital Fortress</b>, <b>Angels &amp; Demons</b>, and <b>Deception Point</b>. He lives in New England.",
#             "rgcopy": "While in Paris on business, Harvard symbologist Robert Langdon receives an urgent late-night phone call: the elderly curator of the Louvre has been murdered inside the museum. Near the body, police have found a baffling cipher. Solving the enigmatic riddle, Langdon is stunned to discover it leads to a trail of clues hidden in the works of Da Vinci...clues visible for all to see...and yet ingeniously disguised by the painter.<br><br>Langdon joins forces with a gifted French cryptologist, Sophie Neveu, and learns the late curator was involved in the Priory of Sion&#8212;an actual secret society whose members included Sir Isaac Newton, Botticelli, Victor Hugo, and Da Vinci, among others. The Louvre curator has sacrificed his life to protect the Priory's most sacred trust: the location of a vastly important religious relic, hidden for centuries. <br><br>In a breathless race through Paris, London, and beyond, Langdon and Neveu match wits with a faceless powerbroker who appears to work for Opus Dei&#8212;a clandestine, Vatican-sanctioned Catholic sect believed to have long plotted to seize the Priory's secret. Unless Langdon and Neveu can decipher the labyrinthine puzzle in time, the Priory's secret&#8212;and a stunning historical truth&#8212;will be lost forever. <br><br>In an exhilarating blend of relentless adventure, scholarly intrigue, and cutting wit, symbologist Robert Langdon (first introduced in Dan Brown's bestselling <b>Angels &amp; Demons</b>) is the most original character to appear in years. <b>The Da Vinci Code</b> heralds the arrival of a new breed of lightening-paced, intelligent thriller...surprising at every twist, absorbing at every turn, and in the end, utterly unpredictable...right up to its astonishing conclusion.",
#             "rgdiscussion": "<p>1. As a symbologist, Robert Langdon has a wealth of academic knowledge that helps him view the world in a unique way. Now that you've read <b>The Da Vinci Code</b>, are there any aspects of life/history/faith that you are seeing in a different light?</p><p>2. Langdon and Teabing disagree as to whether the Sangreal documents should be released to the world. If you were the Grand Master of the Priory of Sion, would you release the documents? If so, what do you think their effect would be?</p><p>3. What observations does this novel make about our past? How do these ideas relate to our future?</p><p>4. Other than his fear of being framed for murder, what motivates Langdon to follow this perilous quest? Do his motivations change?</p><p>5. The novel's &quot;quest&quot; involves numerous puzzles and codes. Did you enjoy trying to solve these puzzles along with the characters? Did you solve any of the puzzles before the characters did?</p><p>6. If you could spend a day in any of the places described in this novel, where would it be, and why? The Louvre? Westminster Abbey? Rosslyn Chapel? The Temple Church? Somewhere else?</p><p>7. Historian Leigh Teabing claims the founding fathers of Christianity hijacked the good name of Jesus for political reasons. Do you agree? Does the historical evidence support Teabing's claim?</p><p>8. Has this book changed your ideas about faith, religion, or history in any way?</p><p>9. Would you rather live in a world without religion or a world without science?</p><p>10. Sauni&#232;re placed a lot of confidence in Langdon. Was this confidence well-placed? What other options might Sauni&#232;re have had? Did Sauni&#232;re make the right decision separating Sophie from the rest of her family?</p><p>11. Do you imagine Langdon should forgive Teabing for his misguided actions? On the other hand, do you think Teabing should forgive Langdon for refusing to release the Sangreal documents?</p><p>12. Does the world have a right to know <i>all</i> aspects of its history, or can an argument be made for keeping certain information secret?</p><p>13. What is interesting about the way this story is told? How are the episodes of the novel arranged and linked? In your discussion, you might want to identify where the turning points in the action are where those moments are after which everything is different. Did you anticipate them?</p><p>14. What is the novel's theme? What central message or idea links all the other components of the novel together?</p><p>15. For most people, the word &quot;God&quot; feels holy, while the word &quot;Goddess&quot; feels mythical. What are your thoughts on this? Do you imagine those perceptions will ever change?</p><p>16. Will you look at the artwork of Da Vinci any differently now that you know more about his &quot;secret life?&quot;</p>",
#             "salestatus": "IP",
#             "subjectcategory1": "FIC030000",
#             "subjectcategory2": "FIC022060",
#             "subjectcategory3": "FIC026000",
#             "subjectcategorydescription1": "Fiction - Thrillers - Suspense",
#             "subjectcategorydescription2": "Fiction - Mystery & Detective - Historical",
#             "subjectcategorydescription3": "Fiction - Religious",
#             "tgpdf": "true",
#             "themes": null,
#             "titleauthisbn": "The Da Vinci Code : Dan Brown : 0307277674 : 0-307-27767-4 : 9780307277671 : 978-0-307-27767-1",
#             "titleshort": "DA VINCI CODE, THE",
#             "titlesubtitleauthisbn": "The Da Vinci Code :  : Dan Brown : 0307277674 : 0-307-27767-4 : 9780307277671 : 978-0-307-27767-1",
#             "titleweb": "The Da Vinci Code",
#             "updatedOn": "2021-02-01T11:25:28.000",
#             "webdomains": {
#                 "webdomain": [
#                     {
#                         "@domain": "ACM.CA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "ACMART",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "BC.CA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "CA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "CAN",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "COMPCOP",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.CA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.CA_",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.NA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.US",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.US_",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "SALESIN",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "SALESPL",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "USA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "USA3PD",
#                         "@sell": "true"
#                     }
#                 ]
#             },
#             "workid": "19309"
#         },
#         {
#             "@uri": "https://reststop.randomhouse.com/resources/titles/9780307474278",
#             "acmartflap": "<b>PREMIUM MASS MARKET EDITION</b><br><br>While in Paris, Harvard symbologist Robert Langdon is awakened by a phone call in the dead of the night. The elderly curator of the Louvre has been murdered inside the museum, his body covered in baffling symbols. As Langdon and gifted French cryptologist Sophie Neveu sort through the bizarre riddles, they are stunned to discover a trail of clues hidden in the works of Leonardo da Vinci&mdash;clues visible for all to see and yet ingeniously disguised by the painter.<br><br>Even more startling, the late curator was involved in the Priory of Sion&mdash;a secret society whose members included Sir Isaac Newton, Victor Hugo, and Da Vinci&mdash;and he guarded a breathtaking historical secret. Unless Langdon and Neveu can decipher the labyrinthine puzzle&mdash;while avoiding the faceless adversary who shadows their every move&mdash;the explosive, ancient truth will be lost forever.<br><br>\"Read the book and be enlightened.\" &mdash;<i>The Washington Post Book World<br></i><br>&ldquo;Blockbuster perfection. . . . A gleefully erudite suspense novel.&rdquo;&mdash;<i>The New York Times</i>",
#             "author": "BROWN, DAN",
#             "authorbio": "Dan Brown is the bestselling author of <b>Digital Fortress</b>, <b>Angels &amp; Demons</b>, and <b>Deception Point</b>. He lives in New England.",
#             "authors": {
#                 "authorId": {
#                     "$": "3446",
#                     "@contributortype": "A"
#                 }
#             },
#             "authorweb": "Dan Brown",
#             "awards": null,
#             "characters": null,
#             "contributorfirst1": "Dan",
#             "contributorlast1": "Brown",
#             "division": "Knopf",
#             "excerpt": "1<br><br>Robert Langdon awoke slowly.<br><br>A telephone was ringing in the darkness--a tinny, unfamiliar ring. He fumbled for the bedside lamp and turned it on. Squinting at his surroundings he saw a plush Renaissance bedroom with Louis XVI furniture, hand-frescoed walls, and a colossal mahogany four-poster bed.<br><br><i>Where the hell am I?</i><br><br>The jacquard bathrobe hanging on his bedpost bore the monogram: <br><br>HOTEL RITZ PARIS.<br><br>Slowly, the fog began to lift.<br><br>Langdon picked up the receiver. &quot;Hello?&quot;<br><br>&quot;Monsieur Langdon?&quot; a man's voice said. &quot;I hope I have not awoken you?&quot;<br><br>Dazed, Langdon looked at the bedside clock. It was 12:32 A.M. He had been asleep only an hour, but he felt like the dead.<br><br>&quot;This is the concierge, monsieur. I apologize for this intrusion, but you have a visitor. He insists it is urgent.&quot;<br><br>Langdon still felt fuzzy. A <i>visitor</i>? His eyes focused now on a crumpled flyer on his bedside table.<br><br>THE AMERICAN UNIVERSITY OF PARIS<br>proudly presents<br>An evening with Robert Langdon<br>Professor of Religious Symbology, Harvard University<br><br>Langdon groaned. Tonight's lecture--a slide show about pagan symbolism hidden in the stones of Chartres Cathedral--had probably ruffled some conservative feathers in the audience. Most likely, some religious scholar had trailed him home to pick a fight.<br><br>&quot;I'm sorry,&quot; Langdon said, &quot;but I'm very tired and--&quot;<br><br><i>&quot;Mais monsieur</i>,&quot; the concierge pressed, lowering his voice to an urgent whisper. &quot;Your guest is an important man.&quot;<br><br>Langdon had little doubt. His books on religious paintings and cult symbology had made him a reluctant celebrity in the art world, and last year Langdon's visibility had increased a hundred-fold after his involvement in a widely publicized incident at the Vatican. Since then, the stream of self-important historians and art buffs arriving at his door had seemed never-ending.<br><br>&quot;If you would be so kind,&quot; Langdon said, doing his best to remain polite, &quot;could you take the man's name and number, and tell him I'll try to call him before I leave Paris on Tuesday? Thank you.&quot; He hung up before the concierge could protest.<br><br>Sitting up now, Langdon frowned at his bedside Guest Relations Handbook, whose cover boasted: SLEEP LIKE A BABY IN THE CITY OF LIGHTS. SLUMBER AT THE  PARIS RITZ.<br><br>He turned and gazed tiredly into the full-length mirror across the room. The man staring back at him was a stranger--tousled and weary.<br><br><i>You need a vacation, Robert.</i><br><br>The past year had taken a heavy toll on him, but he didn't appreciate seeing proof in the mirror. His usually sharp blue eyes looked hazy and drawn tonight. A dark stubble was shrouding his strong jaw and dimpled chin. Around his temples, the gray highlights were advancing, making their way deeper into his thicket of coarse black hair. Although his female colleagues insisted the gray only accentuated his bookish appeal, Langdon knew better.<br><br>If <i>Boston Magazine</i> could see me now.<br><br>Last month, much to Langdon's embarrassment, <i>Boston Magazine</i> had listed him as one of that city's top ten most intriguing people--a dubious honor that made him the brunt of endless ribbing by his Harvard colleagues. Tonight, three thousand miles from home, the accolade had resurfaced to haunt him at the lecture he had given.<br><br>&quot;Ladies and gentlemen . . .&quot; the hostess had announced to a full-house at The American University of Paris's <i>Pavillon Dauphine</i>, &quot;Our guest tonight needs no introduction. He is the author of numerous books: <i>The Symbology of Secret Sects, The Art of the Illuminati, The Lost Language of Ideograms</i>, and when I say he wrote the book on Religious Iconology, I mean that quite literally. Many of you use his textbooks in class.&quot; ...
#             "flapcopy": "<p><b>MORE THAN 80 MILLION COPIES SOLD<br><br><b><b>Nominated as one of America&rsquo;s best-loved novels by PBS&rsquo;s&#160;<i>The Great American Read</i></b></b></b><br><br>While in Paris, Harvard symbologist Robert Langdon is awakened  by a phone call in the dead of the night. The elderly curator of the Louvre has been  murdered inside the museum, his body covered in baffling symbols. As Langdon and  gifted French cryptologist Sophie Neveu sort through the bizarre riddles, they are  stunned to discover a trail of clues hidden in the works of Leonardo da Vinci&mdash;clues  visible for all to see and yet ingeniously disguised by the painter.</p><p>Even more startling,  the late curator was involved in the Priory of Sion&mdash;a secret society whose members  included Sir Isaac Newton, Victor Hugo, and Da Vinci&mdash;and he guarded a breathtaking  historical secret. Unless Langdon and Neveu can decipher the labyrinthine puzzle&mdash;while  avoiding the faceless adversary who shadows their every move&mdash;the explosive, ancient  truth will be lost forever.</p>",
#             "formatcode": "MM",
#             "formatname": "Paperback",
#             "imprint": "Anchor",
#             "isbn": "9780307474278",
#             "isbn10": "0307474275",
#             "isbn10hyphenated": "0-307-47427-5",
#             "isbn13hyphenated": "978-0-307-47427-8",
#             "jacketquotes": "&quot;Read the book and be enlightened.&quot; &#8212;<i>The Washington Post Book World</i>&#8220;A pulse-quickening, brain-teasing adventure.&#8221; &#8212;<i>People</i>&#8220;Thriller writing doesn't get any better than this.&#8221; &#8212;<i>The Denver Post</i>&#8220;Blockbuster perfection.&#8221;&#8212;<i>The New York Times</i>",
#             "keyword": "The Da Vinci Code :  : Dan Brown : Anchor : Fiction - Thrillers - Suspense : Fiction - Mystery & Detective - Historical : Fiction - Religious : 0307474275 : 0-307-47427-5 : 9780307474278 : 978-0-307-47427-8 : <p><b>MORE THAN 80 MILLION COPIES SOLD<br><br><b><b>Nominated as one of America&rsquo;s best-loved novels by PBS&rsquo;s&#160;<i>The Great American Read</i></b></b></b><br><br>While in Paris, Harvard symbologist Robert Langdon is awakened  by a phone call in the dead of the night. The elderly curator of the Louvre has been  murdered inside the museum, his body covered in baffling symbols. As Langdon and  gifted French cryptologist Sophie Neveu sort through the bizarre riddles, they are  stunned to discover a trail of clues hidden in the works of Leonardo da Vinci&mdash;clues  visible for all to see and yet ingeniously disguised by the painter.</p><p>Even more startling,  the late curator was involved in the Priory of Sion&mdash;a secret society whose members  included Sir Isaac Newton, Victor Hugo, and Da Vinci&mdash;and he guarded a breathtaking  historical secret. Unless Langdon and Neveu can decipher the labyrinthine puzzle&mdash;while  avoiding the faceless adversary who shadows their every move&mdash;the explosive, ancient  truth will be lost forever.</p>",
#             "links": {
#                 "link": {
#                     "ean": "9780307474278",
#                     "linkattr": "3000",
#                     "linkid": "3485",
#                     "linktext": "The Official Dan Brown Site",
#                     "url": "http://www.danbrown.com",
#                     "weblinkisbn": "30747427"
#                 }
#             },
#             "onsaledate": "03/31/2009",
#             "pages": "624",
#             "pricecanada": "12.99",
#             "priceusa": "9.99",
#             "relatedisbns": {
#                 "isbn": [
#                     {
#                         "$": "9780739340653",
#                         "@formatcode": "DN"
#                     },
#                     {
#                         "$": "9780307474278",
#                         "@formatcode": "MM"
#                     },
#                     {
#                         "$": "9780385504218",
#                         "@formatcode": "EL"
#                     },
#                     {
#                         "$": "9781415934777",
#                         "@formatcode": "DN"
#                     },
#                     {
#                         "$": "9780739326749",
#                         "@formatcode": "TR"
#                     },
#                     {
#                         "$": "9780307277671",
#                         "@formatcode": "TR"
#                     },
#                     {
#                         "$": "9780307879257",
#                         "@formatcode": "CD"
#                     },
#                     {
#                         "$": "9780385504201",
#                         "@formatcode": "HC"
#                     }
#                 ]
#             },
#             "rgabout": "The following questions are intended to enhance your discussion, spotlight memorable passages, and make your reading experience of <b>The Da Vinci Code</b> even livelier.",
#             "rgauthbio": "Dan Brown is the bestselling author of <b>Digital Fortress</b>, <b>Angels &amp; Demons</b>, and <b>Deception Point</b>. He lives in New England.",
#             "rgcopy": "While in Paris on business, Harvard symbologist Robert Langdon receives an urgent late-night phone call: the elderly curator of the Louvre has been murdered inside the museum. Near the body, police have found a baffling cipher. Solving the enigmatic riddle, Langdon is stunned to discover it leads to a trail of clues hidden in the works of Da Vinci...clues visible for all to see...and yet ingeniously disguised by the painter.<br><br>Langdon joins forces with a gifted French cryptologist, Sophie Neveu, and learns the late curator was involved in the Priory of Sion&#8212;an actual secret society whose members included Sir Isaac Newton, Botticelli, Victor Hugo, and Da Vinci, among others. The Louvre curator has sacrificed his life to protect the Priory's most sacred trust: the location of a vastly important religious relic, hidden for centuries. <br><br>In a breathless race through Paris, London, and beyond, Langdon and Neveu match wits with a faceless powerbroker who appears to work for Opus Dei&#8212;a clandestine, Vatican-sanctioned Catholic sect believed to have long plotted to seize the Priory's secret. Unless Langdon and Neveu can decipher the labyrinthine puzzle in time, the Priory's secret&#8212;and a stunning historical truth&#8212;will be lost forever. <br><br>In an exhilarating blend of relentless adventure, scholarly intrigue, and cutting wit, symbologist Robert Langdon (first introduced in Dan Brown's bestselling <b>Angels &amp; Demons</b>) is the most original character to appear in years. <b>The Da Vinci Code</b> heralds the arrival of a new breed of lightening-paced, intelligent thriller...surprising at every twist, absorbing at every turn, and in the end, utterly unpredictable...right up to its astonishing conclusion.",
#             "rgdiscussion": "<p>1. As a symbologist, Robert Langdon has a wealth of academic knowledge that helps him view the world in a unique way. Now that you've read <b>The Da Vinci Code</b>, are there any aspects of life/history/faith that you are seeing in a different light?</p><p>2. Langdon and Teabing disagree as to whether the Sangreal documents should be released to the world. If you were the Grand Master of the Priory of Sion, would you release the documents? If so, what do you think their effect would be?</p><p>3. What observations does this novel make about our past? How do these ideas relate to our future?</p><p>4. Other than his fear of being framed for murder, what motivates Langdon to follow this perilous quest? Do his motivations change?</p><p>5. The novel's &quot;quest&quot; involves numerous puzzles and codes. Did you enjoy trying to solve these puzzles along with the characters? Did you solve any of the puzzles before the characters did?</p><p>6. If you could spend a day in any of the places described in this novel, where would it be, and why? The Louvre? Westminster Abbey? Rosslyn Chapel? The Temple Church? Somewhere else?</p><p>7. Historian Leigh Teabing claims the founding fathers of Christianity hijacked the good name of Jesus for political reasons. Do you agree? Does the historical evidence support Teabing's claim?</p><p>8. Has this book changed your ideas about faith, religion, or history in any way?</p><p>9. Would you rather live in a world without religion or a world without science?</p><p>10. Sauni&#232;re placed a lot of confidence in Langdon. Was this confidence well-placed? What other options might Sauni&#232;re have had? Did Sauni&#232;re make the right decision separating Sophie from the rest of her family?</p><p>11. Do you imagine Langdon should forgive Teabing for his misguided actions? On the other hand, do you think Teabing should forgive Langdon for refusing to release the Sangreal documents?</p><p>12. Does the world have a right to know all aspects of its history, or can an argument be made for keeping certain information secret?</p><p>13. What is interesting about the way this story is told? How are the episodes of the novel arranged and linked? In your discussion, you might want to identify where the turning points in the action are where those moments are after which everything is different. Did you anticipate them?</p><p>14. What is the novel's theme? What central message or idea links all the other components of the novel together?</p><p>15. For most people, the word &quot;God&quot; feels holy, while the word &quot;Goddess&quot; feels mythical. What are your thoughts on this? Do you imagine those perceptions will ever change?</p><p>16. Will you look at the artwork of Da Vinci any differently now that you know more about his &quot;secret life?&quot;</p>",
#             "salestatus": "IP",
#             "subformat": "PR",
#             "subjectcategory1": "FIC030000",
#             "subjectcategory2": "FIC022060",
#             "subjectcategory3": "FIC026000",
#             "subjectcategorydescription1": "Fiction - Thrillers - Suspense",
#             "subjectcategorydescription2": "Fiction - Mystery & Detective - Historical",
#             "subjectcategorydescription3": "Fiction - Religious",
#             "tgpdf": "true",
#             "themes": null,
#             "titleauthisbn": "The Da Vinci Code : Dan Brown : 0307474275 : 0-307-47427-5 : 9780307474278 : 978-0-307-47427-8",
#             "titleshort": "DA VINCI CODE, THE",
#             "titlesubtitleauthisbn": "The Da Vinci Code :  : Dan Brown : 0307474275 : 0-307-47427-5 : 9780307474278 : 978-0-307-47427-8",
#             "titleweb": "The Da Vinci Code",
#             "updatedOn": "2021-02-03T17:05:14.000",
#             "webdomains": {
#                 "webdomain": [
#                     {
#                         "@domain": "ACM.CA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "ACMART",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "BC.CA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "CA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "CAN",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "COMPCOP",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.CA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.CA_",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.NA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.US",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.US_",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "SALESIN",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "SALESPL",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "USA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "USA3PD",
#                         "@sell": "true"
#                     }
#                 ]
#             },
#             "workid": "19309"
#         },
#         {
#             "@uri": "https://reststop.randomhouse.com/resources/titles/9780307736932",
#             "author": "BROWN, DAN",
#             "authors": {
#                 "authorId": [
#                     {
#                         "$": "3446",
#                         "@contributortype": "A"
#                     },
#                     {
#                         "$": "117895",
#                         "@contributortype": "4"
#                     }
#                 ]
#             },
#             "authorweb": "Dan Brown",
#             "awards": null,
#             "characters": null,
#             "contributorfirst1": "Dan",
#             "contributorfirst2": "Gustavo",
#             "contributorlast1": "Brown",
#             "contributorlast2": "Rex",
#             "division": "Audio",
#             "flapcopy": "<i>El s&iacute;mbolo perdido</i>, la sensacional continuaci&oacute;n de <i>El c&oacute;digo Da Vinci</i>, es un golpe maestro de la narrativa: una carrera mortal a trav&eacute;s de un aut&eacute;ntico laberinto compuesto por c&oacute;digos y verdades ocultas, bajo la mirada vigilante de un ser villano aterrador. La acci&oacute;n de <i>El s&iacute;mbolo perdido, </i>que tiene lugar en el interior de una serie de t&uacute;neles y templos ocultos de Washington, cobra ritmo a trav&eacute;s de un asombroso paisaje hacia un final inimaginable.<br>&#160;<br>Robert Langdon, experto en simbolog&iacute;a de la Universidad de Harvard, ha sido convocado al Capitolio para dar una conferencia nocturna. Minutos despu&eacute;s de su llegada, la noche da un giro extra&ntilde;o: se descubre en el Capitolio un objeto perturbador, art&iacute;sticamente cifrado con cinco s&iacute;mbolos vetustos. El objeto es una invitaci&oacute;n antigua cuyo fin es conducir a su destinatario al interior de un mundo de sabidur&iacute;a esot&eacute;rica arcana que se hab&iacute;a perdido hac&iacute;a mucho tiempo. Cuando alguien secuestra a Peter Solomon, mentor de Langdon y destacado mas&oacute;n y fil&aacute;ntropo, la &uacute;nica esperanza que tiene Langdon de salvarlo es aceptar esta invitaci&oacute;n y seguirla hasta donde lo conduzca. Langdon termina sumido en un mundo clandestino de secretos mas&oacute;nicos, historia oculta y lugares que nunca antes se hab&iacute;an visto. Todo esto parece arrastrarlo hacia una &uacute;nica e inconcebible verdad.<br>&#160;<br><i>El s&iacute;mbolo perdido</i> es exactamente lo que los admiradores de Dan Brown han estado esperando: su novela m&aacute;s emocionante hasta el momento.",
#             "formatcode": "DN",
#             "formatname": "Unabridged Audiobook Download",
#             "imprint": "Random House Audio",
#             "isbn": "9780307736932",
#             "isbn10": "0307736938",
#             "isbn10hyphenated": "0-307-73693-8",
#             "isbn13hyphenated": "978-0-307-73693-2",
#             "keyword": "El simbolo perdido :  : Dan Brown : Random House Audio : Fiction - Thrillers - Suspense : Fiction - Occult & Supernatural : Fiction - Mystery & Detective - Historical : 0307736938 : 0-307-73693-8 : 9780307736932 : 978-0-307-73693-2 : <i>El s&iacute;mbolo perdido</i>, la sensacional continuaci&oacute;n de <i>El c&oacute;digo Da Vinci</i>, es un golpe maestro de la narrativa: una carrera mortal a trav&eacute;s de un aut&eacute;ntico laberinto compuesto por c&oacute;digos y verdades ocultas, bajo la mirada vigilante de un ser villano aterrador. La acci&oacute;n de <i>El s&iacute;mbolo perdido, </i>que tiene lugar en el interior de una serie de t&uacute;neles y templos ocultos de Washington, cobra ritmo a trav&eacute;s de un asombroso paisaje hacia un final inimaginable.<br>&#160;<br>Robert Langdon, experto en simbolog&iacute;a de la Universidad de Harvard, ha sido convocado al Capitolio para dar una conferencia nocturna. Minutos despu&eacute;s de su llegada, la noche da un giro extra&ntilde;o: se descubre en el Capitolio un objeto perturbador, art&iacute;sticamente cifrado con cinco s&iacute;mbolos vetustos. El objeto es una invitaci&oacute;n antigua cuyo fin es conducir a su destinatario al interior de un mundo de sabidur&iacute;a esot&eacute;rica arcana que se hab&iacute;a perdido hac&iacute;a mucho tiempo. Cuando alguien secuestra a Peter Solomon, mentor de Langdon y destacado mas&oacute;n y fil&aacute;ntropo, la &uacute;nica esperanza que tiene Langdon de salvarlo es aceptar esta invitaci&oacute;n y seguirla hasta donde lo conduzca. Langdon termina sumido en un mundo clandestino de secretos mas&oacute;nicos, historia oculta y lugares que nunca antes se hab&iacute;an visto. Todo esto parece arrastrarlo hacia una &uacute;nica e inconcebible verdad.<br>&#160;<br><i>El s&iacute;mbolo perdido</i> es exactamente lo que los admiradores de Dan Brown han estado esperando: su novela m&aacute;s emocionante hasta el momento.",
#             "links": null,
#             "onsaledate": "11/24/2009",
#             "pages": "0",
#             "pricecanada": "37.00",
#             "priceusa": "30.00",
#             "relatedisbns": {
#                 "isbn": {
#                     "$": "9780307736932",
#                     "@formatcode": "DN"
#                 }
#             },
#             "salestatus": "EL",
#             "subjectcategory1": "FIC030000",
#             "subjectcategory2": "FIC024000",
#             "subjectcategory3": "FIC022060",
#             "subjectcategorydescription1": "Fiction - Thrillers - Suspense",
#             "subjectcategorydescription2": "Fiction - Occult & Supernatural",
#             "subjectcategorydescription3": "Fiction - Mystery & Detective - Historical",
#             "tgpdf": "false",
#             "themes": null,
#             "titleauthisbn": "El simbolo perdido : Dan Brown : 0307736938 : 0-307-73693-8 : 9780307736932 : 978-0-307-73693-2",
#             "titleshort": "EL SIMBOLO PERDIDO (UAB)(DN)",
#             "titlesubtitleauthisbn": "El simbolo perdido :  : Dan Brown : 0307736938 : 0-307-73693-8 : 9780307736932 : 978-0-307-73693-2",
#             "titleweb": "El simbolo perdido",
#             "updatedOn": "2020-07-31T15:04:28.000",
#             "webdomains": {
#                 "webdomain": [
#                     {
#                         "@domain": "AUDIO",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "BC.CA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "CA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "CAN",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.CA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.CA_",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.NA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.US",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.US_",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "SALESPL",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "USA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "USA3PD",
#                         "@sell": "true"
#                     }
#                 ]
#             },
#             "workid": "203096"
#         },
#         {
#             "@uri": "https://reststop.randomhouse.com/resources/titles/9780307879257",
#             "author": "BROWN, DAN",
#             "authorbio": "<p><b>Dan Brown</b> is the bestselling author of <i>Digital Fortress, Angels &amp; Demons</i>, <i>Deception Point </i>and <i>The Lost Symbol.</i> He lives in New England.</p>",
#             "authors": {
#                 "authorId": [
#                     {
#                         "$": "3446",
#                         "@contributortype": "A"
#                     },
#                     {
#                         "$": "60113",
#                         "@contributortype": "4"
#                     }
#                 ]
#             },
#             "authorweb": "Dan Brown",
#             "awards": null,
#             "characters": null,
#             "contributorfirst1": "Dan",
#             "contributorfirst2": "Paul",
#             "contributorlast1": "Brown",
#             "contributorlast2": "Michael",
#             "division": "Audio",
#             "excerpt": "1<br><br>Robert Langdon awoke slowly.<br><br>A telephone was ringing in the darkness--a tinny, unfamiliar ring. He fumbled for the bedside lamp and turned it on. Squinting at his surroundings he saw a plush Renaissance bedroom with Louis XVI furniture, hand-frescoed walls, and a colossal mahogany four-poster bed.<br><br><i>Where the hell am I?</i><br><br>The jacquard bathrobe hanging on his bedpost bore the monogram: <br><br>HOTEL RITZ PARIS.<br><br>Slowly, the fog began to lift.<br><br>Langdon picked up the receiver. &quot;Hello?&quot;<br><br>&quot;Monsieur Langdon?&quot; a man's voice said. &quot;I hope I have not awoken you?&quot;<br><br>Dazed, Langdon looked at the bedside clock. It was 12:32 A.M. He had been asleep only an hour, but he felt like the dead.<br><br>&quot;This is the concierge, monsieur. I apologize for this intrusion, but you have a visitor. He insists it is urgent.&quot;<br><br>Langdon still felt fuzzy. A <i>visitor</i>? His eyes focused now on a crumpled flyer on his bedside table.<br><br>THE AMERICAN UNIVERSITY OF PARIS<br>proudly presents<br>An evening with Robert Langdon<br>Professor of Religious Symbology, Harvard University<br><br>Langdon groaned. Tonight's lecture--a slide show about pagan symbolism hidden in the stones of Chartres Cathedral--had probably ruffled some conservative feathers in the audience. Most likely, some religious scholar had trailed him home to pick a fight.<br><br>&quot;I'm sorry,&quot; Langdon said, &quot;but I'm very tired and--&quot;<br><br><i>&quot;Mais monsieur</i>,&quot; the concierge pressed, lowering his voice to an urgent whisper. &quot;Your guest is an important man.&quot;<br><br>Langdon had little doubt. His books on religious paintings and cult symbology had made him a reluctant celebrity in the art world, and last year Langdon's visibility had increased a hundred-fold after his involvement in a widely publicized incident at the Vatican. Since then, the stream of self-important historians and art buffs arriving at his door had seemed never-ending.<br><br>&quot;If you would be so kind,&quot; Langdon said, doing his best to remain polite, &quot;could you take the man's name and number, and tell him I'll try to call him before I leave Paris on Tuesday? Thank you.&quot; He hung up before the concierge could protest.<br><br>Sitting up now, Langdon frowned at his bedside Guest Relations Handbook, whose cover boasted: SLEEP LIKE A BABY IN THE CITY OF LIGHTS. SLUMBER AT THE  PARIS RITZ.<br><br>He turned and gazed tiredly into the full-length mirror across the room. The man staring back at him was a stranger--tousled and weary.<br><br><i>You need a vacation, Robert.</i><br><br>The past year had taken a heavy toll on him, but he didn't appreciate seeing proof in the mirror. His usually sharp blue eyes looked hazy and drawn tonight. A dark stubble was shrouding his strong jaw and dimpled chin. Around his temples, the gray highlights were advancing, making their way deeper into his thicket of coarse black hair. Although his female colleagues insisted the gray only accentuated his bookish appeal, Langdon knew better.<br><br>If <i>Boston Magazine</i> could see me now.<br><br>Last month, much to Langdon's embarrassment, <i>Boston Magazine</i> had listed him as one of that city's top ten most intriguing people--a dubious honor that made him the brunt of endless ribbing by his Harvard colleagues. Tonight, three thousand miles from home, the accolade had resurfaced to haunt him at the lecture he had given.<br><br>&quot;Ladies and gentlemen . . .&quot; the hostess had announced to a full-house at The American University of Paris's <i>Pavillon Dauphine</i>, &quot;Our guest tonight needs no introduction. He is the author of numerous books: <i>The Symbology of Secret Sects, The Art of the Illuminati, The Lost Language of Ideograms</i>, and when I say he wrote the book on Religious Iconology, I mean that quite literally. Many of you use his textbooks in class.&quot; ...
#             "flapcopy": "<p><b>MORE THAN 80 MILLION COPIES SOLD<br><br><b><b>Nominated as one of America&rsquo;s best-loved novels by PBS&rsquo;s&#160;<i>The Great American Read</i></b></b></b><br><br>While in Paris, Harvard symbologist Robert Langdon is awakened  by a phone call in the dead of the night. The elderly curator of the Louvre has been  murdered inside the museum, his body covered in baffling symbols. As Langdon and  gifted French cryptologist Sophie Neveu sort through the bizarre riddles, they are  stunned to discover a trail of clues hidden in the works of Leonardo da Vinci&mdash;clues  visible for all to see and yet ingeniously disguised by the painter.</p><p>Even more startling,  the late curator was involved in the Priory of Sion&mdash;a secret society whose members  included Sir Isaac Newton, Victor Hugo, and Da Vinci&mdash;and he guarded a breathtaking  historical secret. Unless Langdon and Neveu can decipher the labyrinthine puzzle&mdash;while  avoiding the faceless adversary who shadows their every move&mdash;the explosive, ancient  truth will be lost forever.</p>",
#             "formatcode": "CD",
#             "formatname": "Abridged Compact Disc",
#             "imprint": "Random House Audio",
#             "isbn": "9780307879257",
#             "isbn10": "0307879259",
#             "isbn10hyphenated": "0-307-87925-9",
#             "isbn13hyphenated": "978-0-307-87925-7",
#             "jacketquotes": "&quot;Read the book and be enlightened.&quot; &#8212;<i>The Washington Post Book World</i>&#8220;A pulse-quickening, brain-teasing adventure.&#8221; &#8212;<i>People</i>&#8220;Thriller writing doesn't get any better than this.&#8221; &#8212;<i>The Denver Post</i>&#8220;Blockbuster perfection.&#8221;&#8212;<i>The New York Times</i>",
#             "keyword": "The Da Vinci Code : A Novel : Dan Brown : Random House Audio : Fiction - Thrillers - Suspense : Fiction - Mystery & Detective - Historical : Fiction - Religious : 0307879259 : 0-307-87925-9 : 9780307879257 : 978-0-307-87925-7 : <p><b>MORE THAN 80 MILLION COPIES SOLD<br><br><b><b>Nominated as one of America&rsquo;s best-loved novels by PBS&rsquo;s&#160;<i>The Great American Read</i></b></b></b><br><br>While in Paris, Harvard symbologist Robert Langdon is awakened  by a phone call in the dead of the night. The elderly curator of the Louvre has been  murdered inside the museum, his body covered in baffling symbols. As Langdon and  gifted French cryptologist Sophie Neveu sort through the bizarre riddles, they are  stunned to discover a trail of clues hidden in the works of Leonardo da Vinci&mdash;clues  visible for all to see and yet ingeniously disguised by the painter.</p><p>Even more startling,  the late curator was involved in the Priory of Sion&mdash;a secret society whose members  included Sir Isaac Newton, Victor Hugo, and Da Vinci&mdash;and he guarded a breathtaking  historical secret. Unless Langdon and Neveu can decipher the labyrinthine puzzle&mdash;while  avoiding the faceless adversary who shadows their every move&mdash;the explosive, ancient  truth will be lost forever.</p>",
#             "links": null,
#             "onsaledate": "10/19/2010",
#             "pages": "0",
#             "pricecanada": "16.99",
#             "priceusa": "14.99",
#             "relatedisbns": {
#                 "isbn": [
#                     {
#                         "$": "9780739340653",
#                         "@formatcode": "DN"
#                     },
#                     {
#                         "$": "9780307474278",
#                         "@formatcode": "MM"
#                     },
#                     {
#                         "$": "9780385504218",
#                         "@formatcode": "EL"
#                     },
#                     {
#                         "$": "9781415934777",
#                         "@formatcode": "DN"
#                     },
#                     {
#                         "$": "9780739326749",
#                         "@formatcode": "TR"
#                     },
#                     {
#                         "$": "9780307277671",
#                         "@formatcode": "TR"
#                     },
#                     {
#                         "$": "9780307879257",
#                         "@formatcode": "CD"
#                     },
#                     {
#                         "$": "9780385504201",
#                         "@formatcode": "HC"
#                     }
#                 ]
#             },
#             "salestatus": "IP",
#             "subjectcategory1": "FIC030000",
#             "subjectcategory2": "FIC022060",
#             "subjectcategory3": "FIC026000",
#             "subjectcategorydescription1": "Fiction - Thrillers - Suspense",
#             "subjectcategorydescription2": "Fiction - Mystery & Detective - Historical",
#             "subjectcategorydescription3": "Fiction - Religious",
#             "subtitle": "A Novel",
#             "tgpdf": "false",
#             "themes": null,
#             "titleauthisbn": "The Da Vinci Code : Dan Brown : 0307879259 : 0-307-87925-9 : 9780307879257 : 978-0-307-87925-7",
#             "titleshort": "DA VINCI CODE (CD)(RI)",
#             "titlesubtitleauthisbn": "The Da Vinci Code : A Novel : Dan Brown : 0307879259 : 0-307-87925-9 : 9780307879257 : 978-0-307-87925-7",
#             "titleweb": "The Da Vinci Code",
#             "updatedOn": "2021-02-03T16:04:45.000",
#             "webdomains": {
#                 "webdomain": [
#                     {
#                         "@domain": "AUDIO",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "BC.CA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "BOT",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "CA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "CAN",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "COMPCOP",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.CA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.CA_",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.NA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.US",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "PRH.US_",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "SALESIN",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "SALESPL",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "USA",
#                         "@sell": "true"
#                     },
#                     {
#                         "@domain": "USA3PD",
#                         "@sell": "true"
#                     }
#                 ]
#             },
#             "workid": "19309"
#         }
#     ]
# }

# %% [markdown]
# #### Get & Print multiple data values from the JSON to print the following values from "each" of the 4 titles returned

# %% [markdown]
# <span style="color:blue">
#     Use a for-loop to get and print the following values from each of the 4 titles returned:
#     <ul>
#         <li>Print the <strong>author</strong> value </li>
#         <li>Print the <strong>titleweb</strong> value </li>
#         <li>Print the <strong>subjectcategorydescription2</strong> value </li>
#         <li>Print the <strong>isbn13hyphenated</strong> value </li>
#         <li>Print the <strong>onsaledate</strong> value </li>
#         <li>Print the <strong>formatname</strong> value </li>
#         <li>Print the <strong>priceusa</strong> value </li>
#         <li>Print the <strong>pricecanada</strong> value </li>
#         <li>Print the <strong>pages</strong> value </li>
#         <li>Print a separator line print('---------') for readability </li>
#     </ul>
# </span>

# %%
# INSERT PRINT STATEMENTS FOR MULTIPLE DATA VALUES FOR EACH OF THE 4 TEXT_JSON ENTRIES
for i in range(4):
    print(text_json['title'][i]['author'])
    print(text_json['title'][i]['titleweb'])
    print(text_json['title'][i]['subjectcategorydescription2'])
    print(text_json['title'][i]['isbn13hyphenated'])
    print(text_json['title'][i]['onsaledate'])
    print(text_json['title'][i]['formatname'])
    print(text_json['title'][i]['priceusa'])
    print(text_json['title'][i]['pricecanada'])
    print(text_json['title'][i]['pages'])
    print('-------------------------------------------------------------------------------')
# Out:
# BROWN, DAN
# The Da Vinci Code
# Fiction - Mystery & Detective - Historical
# 978-0-307-27767-1
# 03/28/2006
# Trade Paperback
# 16.95
# 22.95
# 480
# -------------------------------------------------------------------------------
# BROWN, DAN
# The Da Vinci Code
# Fiction - Mystery & Detective - Historical
# 978-0-307-47427-8
# 03/31/2009
# Paperback
# 9.99
# 12.99
# 624
# -------------------------------------------------------------------------------
# BROWN, DAN
# El simbolo perdido
# Fiction - Occult & Supernatural
# 978-0-307-73693-2
# 11/24/2009
# Unabridged Audiobook Download
# 30.00
# 37.00
# 0
# -------------------------------------------------------------------------------
# BROWN, DAN
# The Da Vinci Code
# Fiction - Mystery & Detective - Historical
# 978-0-307-87925-7
# 10/19/2010
# Abridged Compact Disc
# 14.99
# 16.99
# 0
# -------------------------------------------------------------------------------
