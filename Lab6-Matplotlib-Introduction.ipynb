# %% [markdown]
# # Lab 6: Matplotlib Introduction

# %% [markdown]
# ### Author: <font color='red'> Charles Moore </font>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>IMPORTANT: </b> <br>
# This lab was created using a Jupyter Notebook template provided via GitHub <br>
# and provided as supporting content to YouTube video tutorials created by <strong>Data 360 YP</strong> <br>
#     <strong>REF:</strong> https://youtu.be/0QLJduh1MNM  <br>
#     <strong>REF:</strong> https://youtu.be/ikKD-RuYlSw
# </div>

# %% [markdown]
# ## What is Matplotlib?
#
# - Matplotlib is a 2D python plotting library (similar interface with Matlab)
#     - Visualize the data
#     - Identify Trends
#     - Identify outliers
#
#
# - Compatible with both NumPy and Pandas for plotting

# %%
# Visual representation of Pandas
import os
from IPython.display import Image
Image(filename = "matplotlib-logo.jpg", width=600, height=300)

# %% [markdown]
# ## Tutorial Overview
#
# - What is matplotlib and how/why it's used
#
# ### Using Numpy
# - Line plots using NumPy
# - Scatter Plots using NumPy
# - Bar plots & Subplots using Numpy
# - Histogram using NumPy
#
# ### Using Pandas
# - Line Plots using Pandas
# - Combo (Line & Bar) Plots using Pandas df
# - Scatterplot Using DFs
# - Scatterplots with Legends using Pandas

# %% [markdown]
# ## Importing / Installing packages

# %%
# Packages / libraries
import os #provides functions for interacting with the operating system
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# To install Pandas type "pip install matloplib" to the anaconda terminal

# %% [markdown]
# ## 1. Line Graphs using Matplotlib & Numpy (8 pts)

# %% [markdown]
# <span style="color:blue">
# 1. Create a <strong>NumPy array</strong> named <strong>a</strong> with the values [1,2,3,4,5] <br>
# 2. <strong>Plot</strong> array <strong>a</strong> <br>
# 3. <strong>Show</strong> the plot
# </span>

# %%
# INSERT CODE FOR STEPS 1 - 3 
# Creating an array
a = np.array([1,2,3,4,5])
plt.plot(a)
plt.show()

# %% [markdown]
# <span style="color:blue">
#     <strong>Creating 2 arrays - ATTEMPT 1</strong> <br>
#     4. Create a second <strong>NumPy array</strong> named <strong>b</strong> with the values <strong>[2,2,2,2,2]</strong> <br>
#     5. <strong>Plot</strong> arrays <strong>a</strong> and <strong>b</strong> using the command <strong>plt.plot(a,b)</strong> <br>
#     6. <strong>Show</strong> the plot
# </span>

# %%
# INSERT CODE FOR STEPS 4 - 6
# Creating 2 arrays - ATTEMPT 1
b = np.array([2,2,2,2,2])
plt.plot(a,b)
plt.show()

# %% [markdown]
# ### QUESTIONS (4 pts)

# %% [markdown]
# <span style="color:blue">
#     <strong>QUESTION1:</strong> How many lines are plotted on the graph? <br>
#     <strong>QUESTION2:</strong> Which value(s) are plotted?
# </span>

# %%
# INSERT ANSWERS TO QUESTIONS 1 & 2 HERE
#1 line is plotted on the graph
#Value = 2

# %% [markdown]
# <span style="color:blue">
#     <strong>Creating 2 arrays - ATTEMPT 2</strong> <br>
#     7. <strong>Change</strong> the <strong>plt.plot(a,b)</strong> command to 2 separate plot commands: <strong>plt.plot(a)</strong> and <strong>plt.plot(b)</strong> <br>
# 8. <strong>Show</strong> the plot
# </span>

# %%
# INSERT CODE FOR STEPS 7 - 8
# Creating 2 arrays - ATTEMPT 2
plt.plot(a)
plt.plot(b)
plt.show()

# %% [markdown]
# ### 1.5 Change various characteristics of the plot (9 pts)
# #### Increase the size, add a title, change plot line colors, etc.

# %% [markdown]
# <span style="color:blue">
#     1. <strong>Change</strong> the <strong>size</strong> of the plot to <strong>(15,10)</strong> <br>[HINT: Use <strong>plt.figure? help</strong> to get the correct syntax]<br>
#     2. <strong>Plot</strong> array <strong>a</strong> with the following attributes: <strong>color = green; line style of '-.'</strong> and <strong>label = "Rent FY2020"</strong> <br>
#     3. <strong>Plot</strong> array <strong>b</strong> with the following attributes: <strong>line width = 5.</strong> and <strong>label = "AVG Rent"</strong> <br>
#     4. <strong>Plot</strong> array <strong>c</strong> with the following attributes: <strong>color = red; line style of '--'</strong> and <strong>label = "Rent FY2019"</strong> <br>
#     5. <strong>Add</strong> a <strong>title</strong> to the plot. Set the title to <strong>"Rent per Month Summary"</strong>, the <strong>font size = 15</strong>, and the <strong>font weight = 'bold'</strong> <br>
#     6. <strong>Add</strong> a <strong>legend</strong> to the plot. Position the legend in the <strong>upper left</strong> with a <strong>fontsize = 15</strong> <br>
#     7. Define <strong>xticks</strong> on the plot. Specify the <strong>range of (0,len(a))</strong> and values of <strong>'Jan', 'Feb', 'Mar', 'Apr', 'May'</strong> <br>
#     8. Define labels for each <strong>axis</strong>. Label the <strong>x-axis</strong> to be <strong>Months</strong> and the <strong>y-axis</strong> to be <strong>Rent &dollar;</strong> <br>
#     9. <strong>Show</strong> the plot
# </span>

# %%
# Change various characteristics of the plot

# Repeat the creation of the arrays and add a third array named 'c'
a = np.array([1,2,3,4,5])
b = np.array([2,2,2,2,2])
c = np.array([3,2,4,6,5])

# INSERT CODE FOR STEPS 1 - 9

# Increate the size
plt.figure(figsize=(15,10))

# Define the plots: a, b & c
plt.plot(a, c='green', linestyle = '-.', label="Rent FY2020")
plt.plot(b, linewidth=5, label="AVG Rent")
plt.plot(c, c= 'red', linestyle = '--', label = "Rent FY2019")

# Add a title
plt.title("Rent Per Month Summary", fontsize=15, fontweight='bold')

# Add a legend
plt.legend(loc= "upper left", fontsize=15)

# Define the xticks 
plt.xticks(range(0,len(a)),('Jan','Feb','Mar','Apr','May'))

# Lable the x-axis and y-axis 
plt.xlabel("Months")
plt.ylabel("Rent $")
# Show the plot
plt.show()

# %% [markdown]
# ## 2. Scatter Plots using Matplotlib & Numpy (9 pts)

# %% [markdown]
# <strong>Note:</strong> To create a Scatter Plot you must have an X & Y values <br>
# <span style="color:blue">
#     1. Create a <strong>NumPy array</strong> named <strong>a</strong> using <strong>.arange</strong> to create an array with <strong>30</strong> values (0-29) <br>
#     2. Create a <strong>NumPy array</strong> named <strong>b</strong> using <strong>.random.randint</strong> to create an array with <strong>30</strong> data points ranging from <strong>0 - 30</strong>  <br>
#     3. Use <strong>.scatter</strong> to create a <strong>scatter plot</strong> of <strong>(a,b)</strong> <br>
#     4. <strong>Show</strong> the plot
# </span>

# %%
# Simple Scatter Plot Example

# NumPy functions that can be used to create the data
#   np.arange: from 0 to the number you specify
#   np.random.randint: From -> To ,Number of numbers you need

# INSERT CODE FOR STEPS 1 - 4
a = np.arange(0,30)
b = np.random.randint(0,30,30)
plt.scatter(a,b)
plt.show()

# %% [markdown]
# <span style="color:blue">
#     5. Create a <strong>NumPy array</strong> named <strong>s</strong> using <strong>.random.randint</strong> to create an array with <strong>30</strong> data points ranging from <strong>0 - 100</strong>  <br>
#     6. Create a <strong>NumPy array</strong> named <strong>t</strong> using <strong>.random.randint</strong> to create an array with <strong>30</strong> data points ranging from <strong>0 - 30</strong>  <br>
#     7. Create a "new" <strong>NumPy array</strong> named <strong>b</strong> by adding array <strong>a</strong> (from previous steps) to array <strong>t</strong> <br>
#     8. Plot the <strong>scatter plot</strong> of <strong>a &amp; b</strong> but with the <strong>color = green</strong> and <strong>size</strong> set to <strong>s</strong> <br>
#     9. <strong>Show</strong> the plot
# </span>

# %%
# Example 2 - Scatter with different size dots

# INSERT CODE FOR STEPS 5 - 9
s = np.random.randint(0,100,30)
t = np.random.randint(0,30,30)
b = a+t
plt.scatter(a,b,c='green',s=s)
plt.show()

# %% [markdown]
# ## 3. Bar Plots using Matplotlib & Numpy (17 pts)

# %% [markdown]
# <strong>Note:</strong> For Bar Plots, you want the categories along the X-axis and the values along the Y-axis. <br>
# <span style="color:blue">
#     1. Create a <strong>list</strong> named <strong>category</strong> with the 3 values <strong>['Account A','Account B','Account C']</strong> <br>
#     2. Create a <strong>NumPy array</strong> named <strong>revenue</strong> using the <strong>list</strong> of values <strong>[300,450,700]</strong>   <br>
#     3. Use <strong>.figure</strong> to define the figure size <strong>(10,10)</strong><br>
#     4. Use <strong>.bar</strong> to create a <strong>bar graph</strong> with a <strong>range 0-3</strong> and the array <strong>revenue</strong> <br>
#     5. Set the <strong>xticks</strong> to the string values in <strong>category</strong>. [HINT: Remember to specify the range.] <br>
#     6. <strong>Show</strong> the plot
# </span>

# %%
# Example 1 - Simple Bar Plot

# INSERT CODE FOR STEPS 1 - 6
# Creating the raw data 
category = ['Account A','Account B','Account C']
revenue = np.array([300,450,700])

# Plotting it
plt.figure(figsize=(10,10))
plt.bar(range(0,len(category)),revenue)
plt.xticks(range(0,len(category)),category)
plt.show()

# %% [markdown]
# ### Creating Subplots

# %% [markdown]
# <span style="color:blue">
#     7. Copy the code to create <strong>category</strong> and <strong>revenue</strong> from the previous cell (Steps 1-2)<br>
#     8. Use <strong>.figure</strong> to define the figure size <strong>(10,5)</strong> (a bit smaller)<br>
#     9. Use <strong>.subplot(1,3,1)</strong> define a subplot with the <strong>row = 1; column = 3, and index 1</strong> <br>
#     10. Copy the code to create <strong>bar graph</strong> and <strong>xticks</strong> from the previous cell (Steps 4-5)<br>
#     11. Use <strong>.subplot(1,3,2)</strong> define a subplot with the <strong>row = 1; column = 3, and index 2</strong> <br>
#     12. Use <strong>.plot</strong> to create a <strong>line plot</strong> with a <strong>range(0,3)</strong> using <strong>revenue</strong> as the values and set the <strong>color = red</strong> <br>
#     13. Set the <strong>xticks</strong> to the string values in <strong>category</strong>. (same as in bar plot)  <br>
#     14. Use <strong>.subplot(1,3,3)</strong> define a subplot with the <strong>row = 1; column = 3, and index 3</strong> <br>
#     15. Use <strong>.scatter</strong> to create a <strong>scatter plot</strong> with a <strong>range(0,3)</strong> using <strong>revenue</strong> as the values and set the <strong>color = green</strong> <br>
#     16. Set the <strong>xticks</strong> to the string values in <strong>category</strong>. (same as in bar plot)  <br>
#     17. <strong>Show</strong> the plot
# </span>

# %%
# Example 2 - Creating Subplots  (3 plots: bar, line & scatter)

# INSERT CODE FOR STEPS 7 - 17
# Creating the raw data
category = ['Account A','Account B','Account C']
revenue = np.array([300,450,700])

# Plotting it (set figure size)
plt.figure(figsize=(10,5))

# bar
plt.subplot(1,3,1)
plt.bar(range(0,len(category)),revenue)
plt.xticks(range(0,len(category)),category)

# line
plt.subplot(1,3,2)
plt.plot(range(0,len(category)),revenue, c='red')
plt.xticks(range(0,len(category)),category)


# scatter
plt.subplot(1,3,3)
plt.scatter(range(0,len(category)),revenue, c='green')
plt.xticks(range(0,len(category)),category)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## 4. Histogram (5 pts)

# %% [markdown]
# <strong>Note:</strong> Histograms show data distribution to see if data is normally distributed or if the data is skewed one way or another. <br>
# <span style="color:blue">
#     1. Create a <strong>NumPy array</strong> named <strong>a</strong> using <strong>.random.randn</strong> to generate a normally distributed array with <strong>10000</strong> multiplied by <strong>10</strong> (to increase sparsity) and add <strong>100</strong>  <br>
#     2. Use <strong>.hist</strong> to create a <strong>histogram</strong> using the array <strong>a</strong> with <strong>7</strong> bins. <br>
#     3. <strong>Add</strong> a <strong>title</strong> to the histogram. Set the title to <strong>"No of Houses per Square M"</strong> <br>
#     4. Define labels for each <strong>axis</strong>. Label the <strong>x-axis</strong> to be <strong>Square M Bins</strong> and the <strong>y-axis</strong> to be <strong>No of houses</strong> <br>
#     5. <strong>Show</strong> the plot
# </span>

# %%
# Example 1 - Histogram

# INSERT CODE FOR STEPS 1 - 5

# Creating the raw data
a  = np.random.randn(10000)*10+100

# plotting
plt.hist(a,7)
plt.title("Number of Houses per Square M")
plt.xlabel("Square M Bins")
plt.ylabel("No of Houses")
plt.show()

# %% [markdown]
# ## 5. Lineplots using Pandas DataFrames (26 pts)

# %%
# Use this is to find your current directory (if needed)
# cwd = os.getcwd()
# cwd

# %% [markdown]
# <span style="color:blue">
#     1. Use Pandas <strong>read_csv</strong> to read the data from file <strong>Marketing Raw Data.csv</strong> into variable <strong>raw_data</strong> <br>
#     2. Display the <strong>shape</strong> of the <strong>raw_data</strong> DataFrame. <br>
#     3. Display the <strong>first 5 rows</strong> of the DataFrame [HINT: Remember the .head() method]
# </span>

# %%
# INSERT CODE FOR STEPS 1 - 3
# Load the data from the file
raw_data = pd.read_csv("Marketing Raw Data.csv")
# Display the shape of the data
print(raw_data.shape)
# Display the first 5 rows of data from the file
raw_data.head()
# Out:
# (182, 6)
#          Date   Day_Name  Visitors  Revenue  Marketing Spend           Promo
# 0  09/11/2020     Monday       707     5211          651.375        No Promo
# 1  10/11/2020    Tuesday      1455    10386         1298.250   Promotion Red
# 2  11/11/2020  Wednesday      1520    12475         1559.375  Promotion Blue
# 3  12/11/2020   Thursday      1726    14414         1801.750        No Promo
# 4  13/11/2020     Friday      2134    20916         2614.500        No Promo

# %% [markdown]
# <span style="color:blue">
#     4. Use <strong>.plot</strong> to create a simple <strong>line graph</strong> of the <strong>Visitors</strong> data. [HINT: Use "Visitors" as the index for raw_data] <br>
#     5. <strong>Show</strong> the plot. <br>
# </span>

# %%
# Example 1 - Simple line graph

# INSERT CODE FOR STEPS 4 - 5
plt.plot(raw_data["Visitors"])
plt.show()

# %% [markdown]
# <span style="color:blue">
#     6. <strong>Copy</strong> the code from Step 4 (above) to re-create the simple <strong>line graph</strong> of the <strong>Visitors</strong> data. <br>
#     7. Set the <strong>xticks</strong> to the string values in <strong>raw_data["Date"]</strong>. <br>
#     The <strong>range</strong> needs to match the number of data points. Use <strong>len(raw_data["Visitors"])</strong> calculate the upper range value. <br>
#     Because there are so many data points, try adding <strong>rotation = 90</strong> to rotate the date values]<br>
#     8. <strong>Show</strong> the plot. <br>
# </span>
# <span style="color:red">
# <strong>NOTE: The date values along the X-axis are still going to look like BLACK SMUDGES </strong>
# </span>

# %%
# Example 2 - Line graphs with xtickers

# INSERT CODE FOR STEPS 6 - 8
plt.plot(raw_data["Visitors"])
plt.xticks(range(0,len(raw_data["Visitors"])),raw_data["Date"],rotation = 90)
plt.show()

# %% [markdown]
# Limit the amount of data plotted to make the graph easier to read.<br>
# <span style="color:blue">
#     9. <strong>Create</strong> an array named <strong>a</strong> with only the last 10 rows of data. Use <strong>raw_data.tail(10)</strong> get only the last 10 rows. <br>
#     <strong>Note:</strong> Because this return rows 172-182, the <strong>index</strong> values need to be reset. <br>
#     10. Add <strong>.reset_index()</strong> to the end of the previous command <br>
#     11. <strong>Copy</strong> the <strong>plot, xticks &amp; show</strong> commands from the previous cell. <br>
#     12. <strong>Change</strong> all references to <strong>raw_data</strong> in the copied lines to <strong>a</strong> so the correct array is used.
# </span>

# %%
# Example 3 - Line graphs with xtickers and less data

# INSERT CODE FOR STEPS 9 - 12
a = raw_data.tail(10).reset_index()
plt.plot(a["Visitors"])
plt.xticks(range(0,len(a["Visitors"])),a["Date"],rotation = 90)
plt.show()

# %% [markdown]
# Continuing to use the array <strong>a</strong> created above (with 10 rows) ... <br>
# <span style="color:blue">
#     13. Use <strong>.figure</strong> to define the figure size <strong>(15,10)</strong> <br>
#     14. Create a <strong>.plot</strong> of the <strong>Visitors</strong> data setting the <strong>label = "No. of Visitors"</strong> and the <strong>linewidth = 5.</strong> <br>
#     15. Create a 2nd <strong>.plot</strong> of the <strong>Revenue</strong> with a <strong>linestyle = "-."</strong> <br>
#     16. <strong>Copy</strong> the <strong>xticks</strong> command from the previous cell. <br>
#     17. Set the <strong>.title</strong> of the prolect to <strong>"Visitors &amp; Revenue by Day"</strong> with a <strong>fontsize = 20</strong> <br>
#     18. Add a <strong>.legend</strong> located in the <strong>upper right</strong> with a <strong>fontsize = 14</strong> <br>
#     19. Add the label <strong>"Dates"</strong> to the X-axis [Using <strong>.xlabel</strong>] <br>
#     20. <strong>Show</strong> the plot.
# </span>

# %%
# Example 4 - 2+ data points on the graph

# INSERT CODE FOR STEPS 13 - 20
plt.figure(figsize=(15,10))
plt.plot(a["Visitors"],label="No. of Visitors", linewidth = 5)
plt.plot(a["Revenue"],linestyle="-.", label = "Revenue")
plt.xticks(range(0,len(a["Visitors"])),a["Date"],rotation = 90)
plt.title("Visitors & Revenue by Day", fontsize=20)
plt.legend(loc="upper right", fontsize=14)
plt.xlabel("Dates")
plt.show()

# %% [markdown]
# Instead of 2 Line graphs, create a Combo graph with a Line and Bar graph ... <br>
# <span style="color:blue">
#     21. <strong>Copy</strong> all the lines of code from the previous cell (to start). <br>
#     22. <strong>Change</strong> the 1st <strong>plt.plot(...)</strong> line graph to a <strong>bar graph</strong><br>
#     - 22a. Change <strong>plt.plot(...)</strong> to <strong>plt.bar(...)</strong> <br>
#     - 22b. Insert the range information, <strong>range(0,len(a["Visitors"]))</strong>, before the 1st parameter. <br>
#     - 22c. The 2nd parameter should now be: <strong>a["Visitors"]</strong> <br>
#     - 22d. The 3rd parameter should now be: <strong>label="No. of Visitors"</strong> <br>
#     - 22e. The 4th parameter should now be: <strong>linewidth=5.</strong> <br>
#     - 22f. Add a 5th parameter of: <strong>color = "green"</strong> <br>
#     23. <strong>Show</strong> the plot.
# </span>

# %%
# Example 5 - Combo graphs

# INSERT CODE FOR STEPS 21 - 23
plt.figure(figsize=(15,10))
plt.bar(range(0,len(a["Visitors"])),a["Visitors"],label="No. of Visitors", linewidth = 5,color='green')
plt.plot(a["Revenue"],linestyle="-.", label = "Revenue")
plt.xticks(range(0,len(a["Visitors"])),a["Date"],rotation = 90)
plt.title("Visitors & Revenue by Day", fontsize=20)
plt.legend(loc="upper right", fontsize=14)
plt.xlabel("Dates")
plt.show()

# %% [markdown]
# Create a Combo graph with 2 Stacked Bar graphs ... <br>
# <span style="color:blue">
#     24. <strong>Copy</strong> all the lines of code from the previous cell (to start). <br>
#     25. <strong>Change</strong> the Revenue <strong>plt.plot(...)</strong> line graph to a <strong>bar graph</strong><br>
#     - 25a. Change <strong>plt.plot(...)</strong> to <strong>plt.bar(...)</strong> <br>
#     - 25b. Insert the range information, <strong>range(0,len(a["Revenue"]))</strong>, as the 1st parameter. <br>
#     - 25c. The 2nd parameter should now be: <strong>a["Revenue"]</strong> <br>
#     - 25d. Change the 3rd parameter (which was linestyle) to: <strong>label="Revenue"</strong> <br>
#     - 25e. Add a 4th parameter of: <strong>linewidth=5.</strong> <br>
#     - 25f. Add a 5th parameter of: <strong>color = "red"</strong> <br>
#     - 25g. __Switch the order of the 2 plt.bar(...) commands so Revenue is plotted before Visitors__<br>
#     26. <strong>Show</strong> the plot.
# </span>

# %%
# Example 6 - Combo stack bars

# INSERT CODE FOR STEPS 24 - 26
plt.figure(figsize=(15,10))
plt.bar(range(0,len(a["Revenue"])),a["Revenue"],label="Revenue", linewidth = 5,color='red')
plt.bar(range(0,len(a["Visitors"])),a["Visitors"],label="No. of Visitors", linewidth = 5,color='green')
plt.xticks(range(0,len(a["Visitors"])),a["Date"],rotation = 90)
plt.title("Visitors & Revenue by Day", fontsize=20)
plt.legend(loc="upper right", fontsize=14)
plt.xlabel("Dates")
plt.show()

# %% [markdown]
# Create a Combo graph with 2 Bar graphs and a Secondary Scale ... <br>
# <span style="color:blue">
# Since the code involved is quite different than previous examples the code has been provided for you. <br>
# Run the cell and review the code used to create the graph
# </span>

# %%
# CODE PROVIDED FOR YOU ... JUST RUN THIS CELL

# Example 7 - Combo 2+ bar graphs + Secondary Scale

weight = .30

a[["Revenue", "Marketing Spend"]].plot(kind="bar", color = ["green", "red"], figsize=(15,10))
a["Visitors"].plot(c="blue", linestyle = "-.", secondary_y=True)

plt.xticks(range(0,len(a["Visitors"])), a["Date"], rotation = 90)
plt.title("Visitors & Revenue by Day", fontsize = 20)
plt.legend(loc="upper left", fontsize=14)
plt.xlabel("Dates")
plt.xlim(-weight, len(a["Visitors"])-weight)
plt.show()

# examples of Kind
# https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html

# %% [markdown]
# ## 6. Scatterplot Using DataFrames (6 pts)

# %% [markdown]
# Return to using complete set of data <strong>(raw_data)</strong> (with 182 rows) ... <br>
# <span style="color:blue">
#     1. Use <strong>.figure</strong> to define the figure size <strong>(15,10)</strong> <br>
#     2. Create a <strong>.scatter</strong> plot of the <strong>raw_data["Revenue"]</strong> and <strong>raw_data["Marketing Spend"]</strong> data setting the <strong>color = "red"</strong> and the <strong>marker = '+'</strong> <br>
#     3. Set the <strong>.title</strong> of the plot to <strong>"Relationship between M. Spend &amp; Revenue"</strong> with a <strong>fontsize = 20</strong> <br>
#     4. Add the label <strong>"Revenue"</strong> to the X-axis [Using <strong>.xlabel</strong>] <br>
#     5. Add the label <strong>"Marketing Spend"</strong> to the Y-axis [Using <strong>.ylabel</strong>] <br>
#     6. <strong>Show</strong> the plot.
# </span>

# %%
# Example 1 - Simple Scatterplot using DataFrames

# INSERT CODE FOR STEPS 1 - 6 
plt.figure(figsize=(15,10))
plt.scatter(raw_data["Revenue"], raw_data["Marketing Spend"], color="red", marker = "+")
plt.title("Relationship between M. Spend & Revenue", fontsize = 20)
plt.xlabel("Revenue")
plt.ylabel("Marketing Spend")
plt.show()

# %%
# Display the first 5 rows of the data
raw_data.head()
# Out:
#          Date   Day_Name  Visitors  Revenue  Marketing Spend           Promo
# 0  09/11/2020     Monday       707     5211          651.375        No Promo
# 1  10/11/2020    Tuesday      1455    10386         1298.250   Promotion Red
# 2  11/11/2020  Wednesday      1520    12475         1559.375  Promotion Blue
# 3  12/11/2020   Thursday      1726    14414         1801.750        No Promo
# 4  13/11/2020     Friday      2134    20916         2614.500        No Promo

# %% [markdown]
# Create a <strong>Scatterplot with groups</strong> ... <br>
# <span style="color:blue">
# Since the code involved is quite different than previous examples the code has been provided for you. <br>
# Run the cell and review the code used to create the graph
# </span>

# %%
# CODE PROVIDED FOR YOU ... JUST RUN THIS CELL

# Example 2 - Scatterplot with groups

groups = raw_data[["Promo","Revenue","Marketing Spend"]].groupby("Promo")
groups

fig, ax = plt.subplots(figsize=(15,10))

for promo, group in groups:
    ax.scatter(group['Revenue'], group['Marketing Spend'], marker = 'x', label=promo)

ax.legend()
plt.title("Relationship between M. Spend & Revenue by Promo", fontsize = 20)
plt.xlabel("Revenue")
plt.ylabel("Marketing Spend")

plt.show()

# %% [markdown]
# Another <strong>Scatterplot with groups</strong> ... <br>
# <span style="color:blue">
# Since the code involved is quite different than previous examples the code has been provided for you. <br>
# Run the cell and review the code used to create the graph
# </span>

# %%
# CODE PROVIDED FOR YOU ... JUST RUN THIS CELL

# Example 3 - Scatterplot with groups

groups = raw_data[["Day_Name","Revenue","Marketing Spend"]].groupby("Day_Name")
groups

fig, ax = plt.subplots(figsize=(15,10))

for promo, group in groups:
    ax.scatter(group['Revenue'], group['Marketing Spend'], marker = 'x', label=promo)

ax.legend()
plt.title("Relationship between M. Spend & Revenue by Day_Name", fontsize = 20)
plt.xlabel("Revenue")
plt.ylabel("Marketing Spend")

plt.show()
